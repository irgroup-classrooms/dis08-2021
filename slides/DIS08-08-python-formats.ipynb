# %% [markdown]
# # DIS08 - Handling Different File Formats like CSV and JSON in Python

# %% [markdown]
# The following Jupyter notebook is based on chapter 14 of [Automatic the Boring Stuff with Python](https://automatetheboringstuff.com) and the tutorials of [RealPython.com](https://realpython.com/python-json).
#
# __CSV__ and __JSON__ are common plaintext formats for storing data. They are easy for programs to parse while still being human readable, so they are often used for simple spreadsheets or web app data. The `csv` and `json` modules greatly simplify the process of reading and writing to CSV and JSON files.
#
# The last lectures have taught you how to basically handle different data structures in Python, like lists or dictionaries, and how to read content from files. One common task is taking data from a variety of formats and parsing it for the particular information you need. These tasks are often specific to the point that commercial software is not optimally helpful. By writing your own scripts, you can make the computer handle large amounts of data presented in these formats.

# %% [markdown]
# # Part 0: Reading and Writing Files (chapter 8)
#
# Variables are a fine way to store data while your program is running, but if you want your data to persist even after your program has finished, you need to save it to a file. You can think of a file's contents as a single string value, potentially gigabytes in size. In this section, you will learn how to use Python to create, read, and save files on the hard drive.
#
# Watch out: Windows and Unix-based systems differ in the way folders are separated. It's a backslash (\) on Windows and forward slashes (/) on OS X and Linux. There are some tricks to work around these differences. For more details, which are beyond the scope of this tutorial, check chapter 8, subsection "Backslash on Windows and Forward Slash on OS X and Linux".

# %%
# where are you right now?
import os
os.getcwd()
# Out:
# '/Users/schaer/ownCloud/00-LEHRE/dis08/08-python-files-panda'

# %%
# open a csv file and read the content, filter some lines and write the results in a file
import os

# the Lord of the Rings file from the last exercise 
tsvFile = open('lotr_clean.csv')

# read each line and put it in a list
lines = tsvFile.readlines()

# iterate over all lines
resultFile = open('frodo.csv','a') # open the file in append mode - new content does not overwrite old content
for line in lines:
    cols = line.split(';') # split the lines
    if cols[1] == 'FRODO':
        print(cols[1] + ';' + str(cols[2]))
        # write the same line into the resultFile. 
        resultFile.write(cols[1] + ';' + cols[2] + '\n') # remember the newline at the end!
resultFile.close()

# %% [markdown]
# ## PART I: CSV Files - The CSV Module
#
# Remeber: Each line in a CSV file represents a row in the spreadsheet, and commas separate the cells in the row. CSV files are simple, lacking many of the features of an Excel spreadsheet. For example, CSV files
#
# * Don’t have types for their values—everything is a string
# * Don’t have settings for font size or color
# * Don’t have multiple worksheets
# * Can’t specify cell widths and heights
# * Can’t have merged cells
# * Can’t have images or charts embedded in them
#
# In the last lecture you learned to parse CSV file "the hard way", without any special support from a specific module. Not every comma in a CSV file represents the boundary between two cells. CSV files also have their own set of escape characters to allow commas and other characters to be included as part of the values. The `split()` method doesn’t handle these escape characters.
#
# This will change today. Enter, __The CSV Module__

# %%
# The csv module comes with Python, so we can import it right away
import csv
# first open the CSV file
exampleFile = open('lotr_clean.csv')
# create a reader object and specify the delimiter used (comma is the default)
exampleReader = csv.reader(exampleFile, delimiter=';')
# such a reader object can be converted to a normal Python list
exampleData = list(exampleReader)
# show the content of this list
exampleData
# Out:
# [['\ufeff', 'char', 'dialog', 'movie'],
#  ['0',
#   'DEAGOL',
#   'Oh Smeagol Ive got one! , Ive got a fish Smeagol, Smeagol!    ',
#   'The Return of the King '],
#  ['1',
#   'SMEAGOL',
#   'Pull it in! Go on, go on, go on, pull it in! \xa0',
#   'The Return of the King '],
#  ['2', 'DEAGOL', 'Arrghh! ', 'The Return of the King '],
#  ['3', 'SMEAGOL', 'Deagol! \xa0', 'The Return of the King '],
#  ['4', 'SMEAGOL', 'Deagol! \xa0', 'The Return of the King '],
#  ['5', 'SMEAGOL', 'Deagol! \xa0', 'The Return of the King '],
#  ['6',
#   'SMEAGOL',
#   'Give us that! Deagol my love \xa0',
#   'The Return of the King '],
#  ['7', 'DEAGOL', 'Why? \xa0', 'The Return of the King '],
#  ['8',
#   'SMEAGOL',
#   "Because' , it's my birthday and I wants it. \xa0",
#   'The Return of the King '],
#  ['9', 'SMEAGOL', '\xa0My precious. \xa0', 'The Return of the King '],
#  ['10', 'SMEAGOL', 'They cursed us\xa0', 'The Return of the King '],
#  ['11', '(GOLLUM', 'Murderer)\xa0', 'The Return of the King '],
#  ['12',
#   'SMEAGOL',
#   "'Murderer' they called us. They cursed us and drove us away.    ",
#   'The Return of the King '],
#  ['13',
#   'SMEAGOL',
#   "Gollum' Gollum' Gollum' , and we wept precious. We wept to be so alone. \xa0",
#   'The Return of the King '],
#  ['14',
#   'SMEAGOL',
#   "and cool, so nice for feet' and we only wish to catch a fish    , so juicy sweet. \xa0",
#   'The Return of the King '],
#  ['15',
#   'SMEAGOL',
#   'And we forgot the taste of bread, the sound of trees and the softness of     the wind. We even forgot our own name. \xa0',
#   'The Return of the King '],
#  ['16', 'FRODO', '    Gandalf?     \xa0 \xa0', 'The Return of the King '],
#  ['17', 'FRODO', '    Oooohhh! ', 'The Return of the King '],
#  ['18', 'MERRY', '    Frodo! \xa0', 'The Return of the King '],
#  ['19', 'GIMLI', '    Aaaahh! \xa0', 'The Return of the King '],
#  ['20', 'FRODO', '    Gimli! \xa0', 'The Return of the King '],
#  ['21', 'GOLLUM', 'My precious!    ', 'The Return of the King '],
#  ['22',
#   'GOLLUM',
#   'Wake up! , Wake up!     ,Wake up sleepies! We must go, yes, we must go at once. \xa0',
#   'The Return of the King '],
#  ['23',
#   'SAM',
#   "Haven't you had any sleep Mr Frodo? \xa0",
#   'The Return of the King '],
#  ['24',
#   'SAM',
#   "And I've gone and had too much. , It must be getting late. \xa0",
#   'The Return of the King '],
#  ['25',
#   'FRODO',
#   "No, it isn't. It isn't midday yet. , The days are growing darker. \xa0",
#   'The Return of the King '],
#  ['26',
#   'GOLLUM',
#   'Come on! Must go! No time! \xa0',
#   'The Return of the King '],
#  ['27',
#   'SAM',
#   "Not before Mr Frodo's had something to eat. \xa0",
#   'The Return of the King '],
#  ['28', 'GOLLUM', 'No time to lose silly! \xa0', 'The Return of the King '],
#  ['29', 'SAM', 'Here.\xa0', 'The Return of the King '],
#  ['30', 'FRODO', 'What about you? \xa0', 'The Return of the King '],
#  ['31',
#   'SAM',
#   "Oh no, I'm not hungry, leastways not for lembas bread. \xa0",
#   'The Return of the King '],
#  ['32', 'FRODO', 'Sam! \xa0', 'The Return of the King '],
#  ['33', 'FRODO', '    Aragorn! \xa0', 'The Return of the King '],
#  ['34',
#   'GANDALF',
#   '    Now come the days of the King. May they be blessed.\xa0',
#   'The Return of the King '],
#  ['35',
#   'ARAGORN',
#   '    This day does not belong to one man, but to all. Let us together rebuild     this world, that we may share in the days of peace. \xa0',
#   'The Return of the King '],
#  ['36',
#   'ARAGORN',
#   "    Et E'rello Endorenna ut'lien. Sinome maruvan ar Hildinyar tenn' Ambar-metta!    \xa0",
#   'The Return of the King '],
#  ['37', 'ARAGORN', '    Hannon le. ', 'The Return of the King '],
#  ['38',
#   'ARAGORN',
#   '    My friends, , you bow to     no-one. \xa0',
#   'The Return of the King '],
#  ['39',
#   'FRODO',
#   '    ,And thus     it was a Fourth Age of Middle Earth began. And the Fellowship of the Ring,     though eternally bound by friendship and love was ended.            Thirteen months to the day since Gandalf sent us on our long journey we find     ourselves looking upon a familiar sight. \xa0',
#   'The Return of the King '],
#  ['40', 'FRODO', '    We were home. \xa0', 'The Return of the King '],
#  ['41', 'PIPPIN', '    Alright! \xa0', 'The Return of the King '],
#  ['42', 'HOBBIT', '    Hey watch the pumpkin.\xa0', 'The Return of the King '],
#  ['43', 'ROSIE', '    Goodnight lads. \xa0', 'The Return of the King '],
#  ['44',
#   'SAM',
#   "Oh alright, but we don't have that much left. We have to be careful or     we are going to run out. You go ahead and eat that Mr Frodo. I've rationed     it, there should be enough. \xa0",
#   'The Return of the King '],
#  ['45', 'FRODO', 'For what? \xa0', 'The Return of the King '],
#  ['46', 'SAM', 'The journey home. \xa0', 'The Return of the King '],
#  ['47',
#   'GOLLUM',
#   'Come Hobbitses, very close now. Very close to Mordor. No safe places here. Hurry. \xa0',
#   'The Return of the King '],
#  ['48',
#   'MERRY',
#   "It's good. Definitely from the Shire. ,Longbottom leaf eh? \xa0",
#   'The Return of the King '],
#  ['49',
#   'PIPPIN',
#   "uhh huh , I feel like I'm back at the Green Dragon. \xa0",
#   'The Return of the King '],
#  ['50', 'MERRY', 'Mmmm , Green Dragon! \xa0', 'The Return of the King '],
#  ['51',
#   'PIPPIN',
#   "A mug of ale in my hand. Putting my feet up on a settle after a hard     day's work. \xa0",
#   'The Return of the King '],
#  ['52',
#   'MERRY',
#   "Only, , you've never done a hard day's work.    \xa0",
#   'The Return of the King '],
#  ['53', 'PIPPIN', 'Ahaha! ', 'The Return of the King '],
#  ['54',
#   'MERRY',
#   'Welcome, my lords to Isengard! \xa0',
#   'The Return of the King '],
#  ['55',
#   'GIMLI',
#   "You young rascals. A merry hunt you've led us on and now we find you     feasting and ' and smoking! \xa0",
#   'The Return of the King '],
#  ['56', 'PIPPIN', '    Hmm? \xa0', 'The Return of the King '],
#  ['57',
#   'FRODO',
#   '    How do you pick up the threads of an old life? How do you go on, when in     your heart you begin to understand there is no going back? There are some     things that time cannot mend. Some hurts that go too deep, that have taken     hold.\xa0',
#   'The Return of the King '],
#  ['58', 'SAM', '    Mr Frodo? What is it? \xa0', 'The Return of the King '],
#  ['59',
#   'FRODO',
#   "    It's been four years to the day since Weathertop Sam. It's never really     healed. \xa0",
#   'The Return of the King '],
#  ['60',
#   'SAM',
#   '    , There and Back Again, a Hobbits tale     by Bilbo Baggins and the Lord of the Rings by Frodo Baggins. You finished     it.\xa0',
#   'The Return of the King '],
#  ['61',
#   'FRODO',
#   "    Not quite. There's room for a little more. \xa0",
#   'The Return of the King '],
#  ['62',
#   'FRODO',
#   "    Bilbo once told me his part in this tale would end. That each of us must     come and go in the telling. Bilbo's story was now over. There would be no     more journeys for him. , save one. \xa0",
#   'The Return of the King '],
#  ['63',
#   'BILBO',
#   '    Tell me again lad, where are we going?\xa0',
#   'The Return of the King '],
#  ['64',
#   'FRODO',
#   '    To the harbour Bilbo. The elves have accorded you a special honour. A place     on the last ship to leave Middle Earth. \xa0',
#   'The Return of the King '],
#  ['65',
#   'BILBO',
#   '    Frodo, any chance of seeing that old Ring of mine again? The one I gave you?\xa0',
#   'The Return of the King '],
#  ['66',
#   'PIPPIN',
#   ' We are sitting on a field of     victory enjoying a few well earned comforts , The salted pork is particularly good. \xa0',
#   'The Return of the King '],
#  ['67', 'GIMLI', "Salted pork' \xa0", 'The Return of the King '],
#  ['68', 'GANDALF', 'Hobbits! \xa0', 'The Return of the King '],
#  ['69',
#   'MERRY',
#   "We're under orders from Treebeard who's taken over management of Isengard.        ",
#   'The Return of the King '],
#  ['70',
#   'TREEBEARD',
#   "Hoooom, young master Gandalf, I'm glad you've come. Wood and water,     stock and stone I can master, but there is a Wizard to manage here locked in     his tower\xa0",
#   'The Return of the King '],
#  ['71', 'ARAGORN', '\xa0, Show yourself.    \xa0', 'The Return of the King '],
#  ['72',
#   'GANDALF',
#   'Be careful. Even in defeat, Saruman is dangerous. \xa0',
#   'The Return of the King '],
#  ['73',
#   'GIMLI',
#   "Well then let's just have his head and be done with it. \xa0",
#   'The Return of the King '],
#  ['74',
#   'GANDALF',
#   'No, we need him alive. We need him to talk. \xa0',
#   'The Return of the King '],
#  ['75',
#   'SARUMAN',
#   'You have fought many wars and slain many men Theoden King and made peace afterwards. Can we not take counsel together as we once did, my old friend?Can we not have peace you and I?\xa0',
#   'The Return of the King '],
#  ['76',
#   'THEODEN',
#   "We shall have peace'. We shall have peace when you answer for the     burning of the Westfold and the children that lie dead there! We shall have peace when the lives of the soldiers whose bodies were hewn even as they lay dead against the gates of the Hornburg' are avenged! When you hang from a gibbet for the sport of your own crows' we shall have peace! \xa0",
#   'The Return of the King '],
#  ['77',
#   'SARUMAN',
#   "Gibbets and crows! Dotard! What do you want Gandalf Grahame? Let me guess' the key of Orthanc? Or perhaps the keys of Barad D'r itself? Along with the crowns of the seven Kings and the rods of the Five Wizards! \xa0",
#   'The Return of the King '],
#  ['78',
#   'GANDALF',
#   "Your treachery has already cost many lives. Thousands more are now at     risk. But you could save them Saruman. You were deep in the enemy's counsel.    \xa0",
#   'The Return of the King '],
#  ['79',
#   'FRODO',
#   "    I'm sorry uncle. I'm afraid I lost it. \xa0",
#   'The Return of the King '],
#  ['80',
#   'BILBO',
#   '    Oh, pity. (He sighs.) I would have like to have held it one last time. \xa0',
#   'The Return of the King '],
#  ['81',
#   'BILBO',
#   '    Oh! Well here is a sight I have never seen before. \xa0',
#   'The Return of the King '],
#  ['82',
#   'GALADRIL',
#   '    The power of the three rings is ended. The time has come for the dominion of     men. \xa0',
#   'The Return of the King '],
#  ['83',
#   'ELROND',
#   "    \xa0I Aear c'n ven na mar. \xa0",
#   'The Return of the King '],
#  ['84',
#   'BILBO',
#   "    I think I'm quite ready for another adventure. \xa0",
#   'The Return of the King '],
#  ['85',
#   'GANDALF',
#   '    Farewell my brave Hobbits. , My work is now finished.    ,Here at last, on the     shores of the sea, comes the end of our Fellowship. , I will not say do not weep for not all     tears are an evil. , It is time Frodo.    \xa0',
#   'The Return of the King '],
#  ['86', 'SAM', '    What does he mean? \xa0', 'The Return of the King '],
#  ['87',
#   'FRODO',
#   '    We set out to save the Shire Sam and it has been saved, but not for me. \xa0',
#   'The Return of the King '],
#  ['88',
#   'SAM',
#   "    , You don't mean that. You can't     leave.\xa0",
#   'The Return of the King '],
#  ['89',
#   'FRODO',
#   '    The last pages are for you Sam. \xa0',
#   'The Return of the King '],
#  ['90',
#   'SARUMAN',
#   "So you have come here for information. I have some for you.    ,Something festers in the heart of Middle Earth. Something that you have failed to see. But the great eye has seen it! Even now he presses his advantage. His attack will come soon.     ,     You are all going to die! But you know this don't you Gandalf? You cannot think that this Ranger will ever sit upon the throne of Gondor. This exile, crept from the shadows will never be crowned King. ,Gandalf does not hesitate to sacrifice those who are closest to him' those he professes to love! Tell me, what words of comfort did you give the Halfling before you sent him to his doom? The path that you have set him on can only lead to death. \xa0",
#   'The Return of the King '],
#  ['91',
#   'GIMLI',
#   "I've heard enough! Shoot him! Stick an arrow in his gob! \xa0",
#   'The Return of the King '],
#  ['92',
#   'GANDALF',
#   'No! Come down Saruman and your life will be spared! \xa0',
#   'The Return of the King '],
#  ['93',
#   'SARUMAN',
#   'Save your pity and your mercy. I have no use for it!    ',
#   'The Return of the King '],
#  ['94',
#   'GANDALF',
#   "Saruman'.. your staff is broken! \xa0",
#   'The Return of the King '],
#  ['95',
#   'THEODEN',
#   'Grima! You need not follow him! You were not always as you are now. You were once a man of Rohan. Come down. \xa0',
#   'The Return of the King '],
#  ['96',
#   'SARUMAN',
#   'A man of Rohan? What is the house of Rohan but a thatched barn where brigands drink in the reek and their brats roll on the floor with the dogs? The victory at Helms Deep does not belong to you Theoden Horse Master. You are a lesser son of greater sires! \xa0',
#   'The Return of the King '],
#  ['97',
#   'THEODEN',
#   "Grima'. Come down! Be free of him! \xa0",
#   'The Return of the King '],
#  ['98',
#   'SARUMAN',
#   'Free? He will never be free!\xa0',
#   'The Return of the King '],
#  ['99', 'GRIMA', 'No! \xa0', 'The Return of the King '],
#  ['100',
#   'FRODO VOICE OVER',
#   '    My dear Sam, you cannot always be torn in two. , You will     have to be one and whole for many years. You have so much to enjoy and to be     and to do. Your part in the story will go on. \xa0',
#   'The Return of the King '],
#  ['101', 'SAM', "    Well, I'm back.\xa0", 'The Return of the King '],
#  ['102',
#   'PIPPIN',
#   "    \xa0I didn't think it would end this way.\xa0 \xa0",
#   'The Return of the King '],
#  ['103',
#   'GANDALF',
#   "  End?  No, the journey doesn't end here.  Death is just another path, one that we all must take.    ,  The grey rain curtain of this world rolls back and all turns to silvered glass.  And then you see it.    \xa0",
#   'The Return of the King '],
#  ['104',
#   'PIPPIN',
#   '  What?  Gandalf?  See what?    \xa0',
#   'The Return of the King '],
#  ['105',
#   'GANDALF',
#   '  White shores and beyond,  a far green country under a swift sunrise.     \xa0',
#   'The Return of the King '],
#  ['106',
#   'PIPPIN',
#   "  Well, , that's not  so bad.    \xa0",
#   'The Return of the King '],
#  ['107', 'GANDALF', "  No.  No it isn't.    \xa0", 'The Return of the King '],
#  ['108',
#   'THEODEN',
#   '  Rally to me!  To meeee!\xa0    \xa0',
#   'The Return of the King '],
#  ['109',
#   'WITCH KING',
#   '    \xa0Feast on his flesh.    \xa0',
#   'The Return of the King '],
#  ['110',
#   'EOWYN',
#   '    \xa0I will kill you if you touch him.    \xa0',
#   'The Return of the King '],
#  ['111',
#   'EOWYN',
#   '    \xa0The City has fallen silent.  There is no warmth left in the sun.    \xa0 \xa0',
#   'The Return of the King '],
#  ['112', 'EOWYN', '  It grows so cold.    \xa0', 'The Return of the King '],
#  ['113',
#   'FARAMIR',
#   "  It's just the damp of the first spring rain.\xa0    \xa0",
#   'The Return of the King '],
#  ['114',
#   'FARAMIR',
#   '  I do not believe this darkness will endure.\xa0    \xa0',
#   'The Return of the King '],
#  ['115',
#   'SAM',
#   "  Look!  The Orcs, they're moving off!\xa0    \xa0",
#   'The Return of the King '],
#  ['116', 'SARUMAN', 'Get down cur! ', 'The Return of the King '],
#  ['117', 'GRIMA', 'Ah! \xa0', 'The Return of the King '],
#  ['118',
#   'GANDALF',
#   "Saruman! You were deep in the enemy's counsel. Tell us what you know! \xa0",
#   'The Return of the King '],
#  ['119',
#   'SARUMAN',
#   'You withdraw your guard and I will tell you where your doom will be     decided. I will not be held prisoner here! \xa0',
#   'The Return of the King '],
#  ['120',
#   'GANDALF',
#   'Send word to all our allies and to every corner of Middle Earth that     still stands free. The enemy moves against us. We need to know where he will     strike. \xa0',
#   'The Return of the King '],
#  ['121',
#   'TREEBEARD',
#   'The filth of Saruman is washing away. Trees will come back to live here. ,Young trees. Wild trees. \xa0',
#   'The Return of the King '],
#  ['122', 'ARAGORN', 'Pippin! ', 'The Return of the King '],
#  ['123', 'TREEBEARD', 'Bless my bark! \xa0', 'The Return of the King '],
#  ['124',
#   'GANDALF',
#   "Peregrin Took. I'll take that my lad! Quickly now! \xa0",
#   'The Return of the King '],
#  ['125',
#   'WITCH KING',
#   "  Do not come between the Nazg'l and his prey.    \xa0",
#   'The Return of the King '],
#  ['126',
#   'ORC',
#   "  Late as usual, pirate scum. ,  There's knifework here needs doing. Come on you sea rats, get off your ships.\xa0    \xa0",
#   'The Return of the King '],
#  ['127',
#   'GIMLI',
#   "  There's plenty for the both of us, may be best Dwarf win!\xa0    \xa0",
#   'The Return of the King '],
#  ['128',
#   'WITCH KING',
#   '  You fool!  No man can kill me.  Die now!    ',
#   'The Return of the King '],
#  ['129', 'EOWYN', '  I am no man!\xa0    \xa0', 'The Return of the King '],
#  ['130',
#   'SAM',
#   '  You see Mr Frodo some luck at last!    \xa0',
#   'The Return of the King '],
#  ['131',
#   'ORC',
#   '  Move it, you slugs!\xa0    \xa0',
#   'The Return of the King '],
#  ['132', 'ORC', '  Come on!  Faster!\xa0    \xa0', 'The Return of the King '],
#  ['133',
#   'ORC',
#   "  Come along you scum! ,  I'll whip you down to the bone!  Come on!  What have I told you.    ,  Get up!    ,  Come on you slugs!  You two are going straight to the front line!  Move it, come on!  Fall in!  Move it! Move it! Move it!\xa0    \xa0",
#   'The Return of the King '],
#  ['134',
#   'ORC',
#   "  To the gate you slugs, now move it! ,  Don't you know we're at war?\xa0    \xa0",
#   'The Return of the King '],
#  ['135',
#   'ORC',
#   '  Company halt!  Inspection!\xa0    \xa0',
#   'The Return of the King '],
#  ['136', 'FRODO', '  Sam!  Help me!\xa0    \xa0', 'The Return of the King '],
#  ['137', 'SAM', '  Mr Frodo!     \xa0', 'The Return of the King '],
#  ['138',
#   'SAM',
#   '  Stand up Mr Frodo.  Stand up!    \xa0',
#   'The Return of the King '],
#  ['139', 'FRODO', "  It's so heavy!\xa0    \xa0", 'The Return of the King '],
#  ['140',
#   'SAM',
#   '  Oh no!  What do I do? ,  What do I do?\xa0    \xa0',
#   'The Return of the King '],
#  ['141',
#   'FRODO',
#   ' Hit me!  Hit me Sam!  Start fighting!\xa0    \xa0',
#   'The Return of the King '],
#  ['142',
#   'SAM',
#   '  Get off of me! ,  Nobody pushes me you filthy maggot!    ,  Get off of me!\xa0    \xa0',
#   'The Return of the King '],
#  ['143',
#   '\xa0GANDALF',
#   '    \xa0 Retreat! The city is breached. Fall back to the second level. Get the     women and children out. Get them out. Retreat. \xa0',
#   'The Return of the King '],
#  ['144',
#   'SOLDIERS ON GATE',
#   '    Come on, come on! \xa0',
#   'The Return of the King '],
#  ['145',
#   'GOTHMOG',
#   '    Move into the city. Kill all in your path. \xa0',
#   'The Return of the King '],
#  ['146',
#   'ORC',
#   '  Break it up!  Break it up!    \xa0',
#   'The Return of the King '],
#  ['147',
#   'GENERAL',
#   "  Oy!  I'll have your guts if you don't shut this rabble down!\xa0    \xa0",
#   'The Return of the King '],
#  ['148', 'FRODO', '    \xa0Go Sam.  Now!     \xa0', 'The Return of the King '],
#  ['149', 'GENERAL', '  Move along scum!     \xa0', 'The Return of the King '],
#  ['150',
#   'CAPTAIN',
#   '  Get back in the line you maggots!  Get back in the line you slugs!\xa0    \xa0',
#   'The Return of the King '],
#  ['151',
#   'FRODO',
#   "  I can't!  I can't' I can't manage the Ring Sam.  It's' it's' such a weight to carry.  It's such a weight.        \xa0",
#   'The Return of the King '],
#  ['152', 'SOLDIER', '    Take them down! \xa0', 'The Return of the King '],
#  ['153',
#   'GANDALF',
#   '    Fight! Fight to the last man. Fight for your lives. \xa0',
#   'The Return of the King '],
#  ['154',
#   'PIPPIN',
#   "    Gandalf! ,     Gandalf! Denethor has lost his mind. He's burning Faramir alive! \xa0",
#   'The Return of the King '],
#  ['155', 'GANDALF', '    Up! Quickly! \xa0', 'The Return of the King '],
#  ['156',
#   'GANDALF',
#   '    ,     Go back to the abyss! Fall into the nothingness that awaits you and your     master! \xa0',
#   'The Return of the King '],
#  ['157',
#   'WITCH KING',
#   '    Do you not know death when you see it, old man? , This is my hour!    \xa0',
#   'The Return of the King '],
#  ['158', 'PIPPIN', '    \xa0Gandalf! \xa0', 'The Return of the King '],
#  ['159', 'PIPPIN', '    AAAAhhh! , \xa0', 'The Return of the King '],
#  ['160',
#   'WITCH KING',
#   '    You have failed! The world of men will fall. \xa0',
#   'The Return of the King '],
#  ['161',
#   'SAM',
#   "    ,  We're going that way, straight as we can.  There's no point carrying anything we're not sure to need.\xa0    \xa0",
#   'The Return of the King '],
#  ['162',
#   'SAM',
#   '  Mr Frodo, look. ,  There is light and beauty up there that no shadow can touch.     \xa0',
#   'The Return of the King '],
#  ['163',
#   'SAM',
#   "  Take mine. ,  There's a few drops left.\xa0    \xa0",
#   'The Return of the King '],
#  ['164',
#   'FRODO',
#   '  There will be none left for the return journey.\xa0    \xa0',
#   'The Return of the King '],
#  ['165',
#   'SAM',
#   "  I don't think there will be a return journey Mr Frodo.\xa0    \xa0",
#   'The Return of the King '],
#  ['166',
#   'SAM',
#   '  Frodo, get down! ,  Hide!\xa0    \xa0',
#   'The Return of the King '],
#  ['167', 'SAM', '    \xa0Frodo!\xa0    \xa0', 'The Return of the King '],
#  ['168', 'PIPPIN', '  Where are they?    \xa0', 'The Return of the King '],
#  ['169',
#   'ARAGORN',
#   '  Let the Lord of the Black Land come forth! ,  Let justice be done upon him!     \xa0',
#   'The Return of the King '],
#  ['170',
#   'MOUTH OF SAURON',
#   '  My master Sauron the Great bids thee welcome.\xa0    \xa0',
#   'The Return of the King '],
#  ['171',
#   'MOUTH OF SAURON',
#   ' Is there any in this rout with authority to treat with me?    \xa0',
#   'The Return of the King '],
#  ['172',
#   'GANDALF',
#   '  We do not come to treat with Sauron, faithless and accursed.    Tell your master this.  The armies of Mordor must disband.  He is to depart these lands, never to return.\xa0    \xa0',
#   'The Return of the King '],
#  ['173',
#   'EOWYN',
#   '    Courage Merry. Courage for our friends. \xa0',
#   'The Return of the King '],
#  ['174',
#   'GOTHMOG',
#   '    Form ranks you maggots. Form ranks. Pikes in front, archers behind.    \xa0',
#   'The Return of the King '],
#  ['175',
#   'THEODEN',
#   '    Eomer, take your Eored down the left flank\xa0',
#   'The Return of the King '],
#  ['176', 'EOMER', '    Flank ready!\xa0', 'The Return of the King '],
#  ['177',
#   'THEODEN',
#   "    Gamling, follow the King's banner down the centre. Grimbold! Take your company right after you pass the wall. Forth and fear no darkness!     , Arise! Arise riders of Theoden. Spears shall be shaken, shields shall be splintered, a sword day, a red day ere the sun rises!!\xa0",
#   'The Return of the King '],
#  ['178',
#   'EOWYN',
#   "    Whatever happens, stay with me. I'll look after you. \xa0",
#   'The Return of the King '],
#  ['179',
#   'THEODEN',
#   "    Ride now, ride now! Ride! Ride for ruin and the world's ending! DEATH!\xa0",
#   'The Return of the King '],
#  ['180', 'ARMY', '    DEATH! \xa0', 'The Return of the King '],
#  ['181', 'THEODEN', '    DEATH! \xa0', 'The Return of the King '],
#  ['182', 'ARMY', '    DEATH! \xa0', 'The Return of the King '],
#  ['183', 'THEODEN', '    DEATH! \xa0', 'The Return of the King '],
#  ['184', 'THEODEN', '    DEATH! \xa0', 'The Return of the King '],
#  ['185',
#   'MOUTH OF SAURON',
#   '  Aha!  Old Greybeard!  I have a token I was bidden to show thee.     \xa0',
#   'The Return of the King '],
#  ['186', 'PIPPIN', '  Frodo!    \xa0', 'The Return of the King '],
#  ['187', 'PIPPIN', '  Frodo!    \xa0', 'The Return of the King '],
#  ['188', 'GANDALF', '  Silence!    \xa0', 'The Return of the King '],
#  ['189', 'MERRY', '  No!\xa0    \xa0', 'The Return of the King '],
#  ['190', 'GANDALF', '  Silence!    \xa0', 'The Return of the King '],
#  ['191',
#   'MOUTH OF SAURON',
#   "  The Halfling was dear to thee I see.  Know that he suffered greatly at the hands of his host.  Who would've thought one so small could endure so much pain?  And he did Gandalf, he did.\xa0    \xa0",
#   'The Return of the King '],
#  ['192',
#   'ARAGORN',
#   '    You may go no further. \xa0',
#   'The Return of the King '],
#  ['193',
#   'ARAGORN',
#   'You will not enter Gondor\xa0',
#   'The Return of the King '],
#  ['194',
#   'BOSON',
#   'Who are you to deny us passage? \xa0',
#   'The Return of the King '],
#  ['195',
#   'ARAGORN',
#   "Legolas, fire a warning shot past the boson's ear. \xa0",
#   'The Return of the King '],
#  ['196', 'GIMLI', 'Mind your aim.\xa0', 'The Return of the King '],
#  ['197',
#   'GIMLI',
#   "Oh! , That's     it, right, we warned you! Prepare to be boarded! \xa0",
#   'The Return of the King '],
#  ['198',
#   'MERCENARY',
#   'Boarded, by you and whose army? \xa0',
#   'The Return of the King '],
#  ['199', 'EOWYN/MERRY', '    DEATH! \xa0', 'The Return of the King '],
#  ['200', 'THEODEN', '    Forth Eorlingas! \xa0', 'The Return of the King '],
#  ['201', 'GOTHMOG', '    FIRE! ', 'The Return of the King '],
#  ['202', 'MERRY', '    DEEEEAAATH!\xa0', 'The Return of the King '],
#  ['203', 'THEODEN', '    CHAAAAARGE! \xa0', 'The Return of the King '],
#  ['204', 'GOTHMOG', '    Fire at will! \xa0', 'The Return of the King '],
#  ['205',
#   'DENETHOR',
#   '    Set a fire in our flesh! \xa0',
#   'The Return of the King '],
#  ['206', 'GANDALF', '    Stay this madness! \xa0', 'The Return of the King '],
#  ['207',
#   'DENETHOR',
#   '    You may triumph in the field of battle for a day, but against the power that     has risen in the east, there is no victory! \xa0',
#   'The Return of the King '],
#  ['208',
#   'DENETHOR',
#   '    NOOOOOO, you will not take my son from me! \xa0',
#   'The Return of the King '],
#  ['209', 'PIPPIN', '    NO! Aaahhh\xa0', 'The Return of the King '],
#  ['210', 'DENETHOR', '    Faramir! \xa0', 'The Return of the King '],
#  ['211', 'DENETHOR', '    Aaaaaahhhh! \xa0', 'The Return of the King '],
#  ['212',
#   'GANDALF',
#   '    So passes Denethor, son of Ecthelion. \xa0',
#   'The Return of the King '],
#  ['213',
#   'MOUTH OF SAURON',
#   " And who is this?  Isildur's heir?  It takes more to make a King than a broken Elvish blade.\xa0    \xa0",
#   'The Return of the King '],
#  ['214',
#   'GIMLI',
#   '  I guess that concludes negotiations.\xa0    \xa0',
#   'The Return of the King '],
#  ['215',
#   'ARAGORN',
#   '    \xa0I do not believe it.  I will not.    \xa0',
#   'The Return of the King '],
#  ['216', 'ARAGORN', 'This army. \xa0', 'The Return of the King '],
#  ['217', 'GOLLUM', 'In there. \xa0', 'The Return of the King '],
#  ['218', 'FRODO', ' What is this place? \xa0', 'The Return of the King '],
#  ['219',
#   'GOLLUM',
#   'Master must go inside the tunnel. \xa0',
#   'The Return of the King '],
#  ['220',
#   'FRODO',
#   "Now that I'm here I don't think I want to. \xa0",
#   'The Return of the King '],
#  ['221',
#   'GOLLUM',
#   "It's the only way. Go in' or go back. \xa0",
#   'The Return of the King '],
#  ['222', 'FRODO', "I can't go back. \xa0", 'The Return of the King '],
#  ['223', 'FRODO', "What's that smell.\xa0", 'The Return of the King '],
#  ['224',
#   'GOLLUM',
#   "Orcses' filth. Orcses come in here sometimes. \xa0",
#   'The Return of the King '],
#  ['225', 'GOLLUM', 'Hurry! This way.\xa0', 'The Return of the King '],
#  ['226', 'FRODO', 'Smeagol? \xa0', 'The Return of the King '],
#  ['227', 'GOLLUM', 'Over here. \xa0', 'The Return of the King '],
#  ['228',
#   'FRODO',
#   'Ah aah! Its sticky, what is it? \xa0',
#   'The Return of the King '],
#  ['229',
#   'GOLLUM',
#   " You'll see. Oh yes, you     will see.\xa0",
#   'The Return of the King '],
#  ['230',
#   'EOMER',
#   '  Drive them to the river.\xa0,\xa0    ',
#   'The Return of the King '],
#  ['231',
#   'THEODEN',
#   '  Make safe the city.,\xa0    ',
#   'The Return of the King '],
#  ['232',
#   'THEODEN',
#   '  Re-form the line!  Re-form the line!,\xa0    ',
#   'The Return of the King '],
#  ['233',
#   'THEODEN',
#   '  Sound the charge.  Take them head-on. Chaaarge!\xa0,\xa0    ',
#   'The Return of the King '],
#  ['234',
#   'ROHIRRIM',
#   '  Cut him down!\xa0,\xa0    ',
#   'The Return of the King '],
#  ['235',
#   'EOWYN',
#   '  Take the reins, pull him left. ,  LEFT!\xa0,\xa0    ',
#   'The Return of the King '],
#  ['236', 'EOMER', '  Aim for the heads! ,\xa0    ', 'The Return of the King '],
#  ['237',
#   'THEODEN',
#   '  Bring it down! Bring it down!  Bring it down!,\xa0    ',
#   'The Return of the King '],
#  ['238', 'EOWYN', '  Merry!\xa0,\xa0    ', 'The Return of the King '],
#  ['239',
#   'FRODO',
#   'Smeagol? (shouts) SMEAGOL! SMEAGOL! \xa0',
#   'The Return of the King '],
#  ['240', 'FRODO', 'Sam. \xa0', 'The Return of the King '],
#  ['241', 'SAM', 'Ow! \xa0', 'The Return of the King '],
#  ['242',
#   'GALADRIEL VOICEOVER',
#   "And you Frodo Baggins, I give you the light of E'rendil, our most beloved star. , May it be a light for you in dark places, when all other lights go out. \xa0",
#   'The Return of the King '],
#  ['243',
#   'FRODO',
#   "Aiya E'rendil Elenion Ancalim' \xa0",
#   'The Return of the King '],
#  ['244',
#   'GOLLUM',
#   "Naughty little fly. Why does he cry? ,Caught in a web. Soon     you'll be eaten. \xa0",
#   'The Return of the King '],
#  ['245',
#   'GOLLUM',
#   'Got away did it precious? Not this time. Not this time.    \xa0',
#   'The Return of the King '],
#  ['246', 'FRODO', 'NO! ', 'The Return of the King '],
#  ['247',
#   'SMEAGOL',
#   "It wasn't us. It wasn't us. ,Smeagol wouldn't hurt master. We promised. You must believe us. It was the precious. The precious made us do it. \xa0",
#   'The Return of the King '],
#  ['248',
#   'FRODO',
#   'I have to destroy it Smeagol. , I have to destroy it for both our sakes. \xa0',
#   'The Return of the King '],
#  ['249', 'GOLLUM', 'NO! , Aaaaaaaaa.\xa0', 'The Return of the King '],
#  ['250',
#   'FRODO',
#   "I'm so sorry Sam.     I'm so sorry. \xa0",
#   'The Return of the King '],
#  ['251',
#   'GIMLI',
#   'What kind of army would linger in such a place? \xa0',
#   'The Return of the King '],
#  ['252',
#   'LEGOLAS',
#   "One that is cursed. Long ago the men of the mountains swore an oath to     the last King of Gondor , to come to his aid, to fight. But when     the time came, when Gondor's need was dire, they fled vanishing into the     darkness of the mountain. And so Isildur cursed them, never to rest until     they had fulfilled their pledge. Who shall call them from the grey twilight,     the forgotten people? The heir of him to whom the oath they swore. From the     North shall he come, need shall drive him. He shall pass the door to the     Paths of the Dead. \xa0",
#   'The Return of the King '],
#  ['253',
#   'GIMLI',
#   'The very warmth of my blood seems stolen away. \xa0',
#   'The Return of the King '],
#  ['254',
#   'LEGOLAS',
#   'The way is shut. It was made by those who are dead , and the dead keep it. The     way is shut. \xa0',
#   'The Return of the King '],
#  ['255', 'ARAGORN', 'Brego! \xa0', 'The Return of the King '],
#  ['256', 'ARAGORN', 'I do not fear death! ', 'The Return of the King '],
#  ['257',
#   'GALADRIEL',
#   'This task was appointed to you, Frodo of the Shire. If you do not find a     way, no one will. \xa0',
#   'The Return of the King '],
#  ['258',
#   'EOMER',
#   "The scouts report Minas Tirith is surrounded. The lower level's in flames. Everywhere, legions of the enemy advance. \xa0",
#   'The Return of the King '],
#  ['259',
#   'THEODEN',
#   'Time is against us. Make ready!\xa0',
#   'The Return of the King '],
#  ['260',
#   'EOWYN',
#   'Take heart Merry. , It will soon be over\xa0',
#   'The Return of the King '],
#  ['261',
#   'MERRY',
#   "My lady. You are fair and brave and have much to live for    , and many who love you. I     know it is too late to turn aside. I know there is not much point now in     hoping. If I were a knight of Rohan capable of great deeds'but I'm not. I'm a Hobbit. And I know I can't save Middle Earth. I just want to help my friends; Frodo, Sam, Pippin. More than anything I wish I could see them again. ",
#   'The Return of the King '],
#  ['262', 'EOMER', 'Prepare to move out! \xa0', 'The Return of the King '],
#  ['263',
#   'THEODEN',
#   'Make haste. We ride through the night. \xa0',
#   'The Return of the King '],
#  ['264', 'EOWYN', 'To battle\xa0', 'The Return of the King '],
#  ['265', 'MERRY', 'To battle\xa0', 'The Return of the King '],
#  ['266', 'GANDALF', 'Back to the gate! Hurry!\xa0', 'The Return of the King '],
#  ['267',
#   'GIMLI',
#   "Well this is a thing unheard of. An elf will go underground, where a     dwarf dare not. Oh. Oh, I'd never hear the end of it. \xa0",
#   'The Return of the King '],
#  ['268',
#   'THEODEN',
#   'We must ride light and swift. It is a long road ahead and man and beast     must reach the end with the strength to fight. \xa0',
#   'The Return of the King '],
#  ['269',
#   'THEODEN',
#   'Little Hobbits do not belong in war Master Meriadoc. \xa0',
#   'The Return of the King '],
#  ['270',
#   'MERRY',
#   'All my friends have gone to battle. I would be ashamed to be left     behind. \xa0',
#   'The Return of the King '],
#  ['271',
#   'THEODEN',
#   'It is a three-day gallop to Minas Tirith and none of my riders can bear     you as a burdon. \xa0',
#   'The Return of the King '],
#  ['272', 'MERRY', ' I want to fight!\xa0', 'The Return of the King '],
#  ['273', 'THEODEN', 'I will say no more. \xa0', 'The Return of the King '],
#  ['274', 'EOWYN', 'Ride with me! \xa0', 'The Return of the King '],
#  ['275', 'MERRY', 'My lady! \xa0', 'The Return of the King '],
#  ['276',
#   'EOMER',
#   'Form up, move out! Form up, move out! \xa0',
#   'The Return of the King '],
#  ['277',
#   'THEODEN',
#   '\xa0Ride! Ride now to Gondor.\xa0',
#   'The Return of the King '],
#  ['278',
#   'GIMLI',
#   'What is it? What do you see? \xa0',
#   'The Return of the King '],
#  ['279',
#   'LEGOLAS',
#   'I see shapes of men and of horses.\xa0',
#   'The Return of the King '],
#  ['280', 'GIMLI', 'Where? \xa0', 'The Return of the King '],
#  ['281',
#   'LEGOLAS',
#   'Pale banners like shreds of cloud. , Spears rise     like winter thickets through a shroud of mist. The dead are following. They     have been summoned. \xa0',
#   'The Return of the King '],
#  ['282',
#   'GIMLI',
#   ' The dead?     Summoned? I knew that! Huh. Huh. , Very good. Very good. , Legolas! \xa0',
#   'The Return of the King '],
#  ['283', 'ARAGORN', 'Do not look down. \xa0', 'The Return of the King '],
#  ['284',
#   'KING OF THE DEAD',
#   'Who enters my domain?\xa0',
#   'The Return of the King '],
#  ['285',
#   'ARAGORN',
#   'One who will have your allegiance. \xa0',
#   'The Return of the King '],
#  ['286',
#   'KING OF THE DEAD',
#   'The dead do not suffer the living to pass. \xa0',
#   'The Return of the King '],
#  ['287', 'ARAGORN', 'You will suffer me! \xa0', 'The Return of the King '],
#  ['288',
#   'KING OF THE DEAD',
#   'The way is shut! It was made by those who are dead. And the dead keep     it. (The Ghostly army closes around them) The way is shut! Now you must die!    \xa0',
#   'The Return of the King '],
#  ['289',
#   'ARAGORN',
#   ' I summon you to     fulfil your oath! \xa0',
#   'The Return of the King '],
#  ['290',
#   'KING OF THE DEAD',
#   'None but the King of Gondor may command me! \xa0',
#   'The Return of the King '],
#  ['291',
#   'SOLDIER',
#   'Make way for the King!\xa0 Make way, the King is here\xa0',
#   'The Return of the King '],
#  ['292', 'SOLDIER', 'My lord!\xa0 ', 'The Return of the King '],
#  ['293',
#   'SOLDIER',
#   '\xa0Hail to you sire!\xa0 \xa0',
#   'The Return of the King '],
#  ['294',
#   'GRIMBOLD',
#   '\xa0I bring 500 men from the Westfold my lord.\xa0 \xa0',
#   'The Return of the King '],
#  ['295',
#   'SOLDIER',
#   'We have 300 more from Fenmarch, Theoden King.\xa0 \xa0',
#   'The Return of the King '],
#  ['296',
#   'KING OF THE DEAD',
#   'That blade was broken!\xa0',
#   'The Return of the King '],
#  ['297',
#   'ARAGORN',
#   'It has been remade. ,     Fight for us and regain your honour. What say you? ,What say you?\xa0',
#   'The Return of the King '],
#  ['298',
#   'GIMLI',
#   'Ach! You waste your time Aragorn. They had no honour in life and they     have none now in death. \xa0',
#   'The Return of the King '],
#  ['299',
#   'ARAGORN',
#   "I am Isildur's heir. Fight for me and I will hold your oaths fulfilled.    ,What say you?    \xa0",
#   'The Return of the King '],
#  ['300',
#   'ARAGORN',
#   'You have my word! Fight and I will release you from this living death!    , What say you? \xa0',
#   'The Return of the King '],
#  ['301', 'GIMLI', 'Stand you traitors! \xa0', 'The Return of the King '],
#  ['302', 'ARAGORN', 'Out! \xa0', 'The Return of the King '],
#  ['303', 'ARAGORN', 'Legolas! Run! \xa0', 'The Return of the King '],
#  ['304', 'KING OF THE DEAD', 'We fight! \xa0', 'The Return of the King '],
#  ['305', 'SOLDIER', 'Open the gate, quick! \xa0', 'The Return of the King '],
#  ['306', 'IROLAS', 'Quick! Hurry! \xa0', 'The Return of the King '],
#  ['307',
#   'DENETHOR',
#   'Faramir! Say not that he has fallen. \xa0',
#   'The Return of the King '],
#  ['308',
#   'IROLAS',
#   'They were outnumbered! None survived. \xa0',
#   'The Return of the King '],
#  ['309',
#   'GOTHMOG',
#   'Fear. The city is rank with it! Ha ha ha ha. Let us ease their pain.     Release the prisoners! \xa0',
#   'The Return of the King '],
#  ['310',
#   'THEODEN',
#   'Where are the riders from Snowbourn?\xa0 \xa0',
#   'The Return of the King '],
#  ['311',
#   'SOLDIER',
#   'None have come my lord.\xa0 \xa0',
#   'The Return of the King '],
#  ['312',
#   'THEODEN',
#   'Six thousand spears, less than half of what I had hoped for.\xa0',
#   'The Return of the King '],
#  ['313',
#   'ARAGORN',
#   'Six thousand will not be enough to break the lines of Mordor.\xa0 \xa0',
#   'The Return of the King '],
#  ['314', 'THEODEN', '\xa0 More will come    \xa0', 'The Return of the King '],
#  ['315',
#   'ARAGORN',
#   "Every hour lost hastens Gondor's defeat.\xa0 ,\xa0 We have until dawn then we must ride.\xa0 \xa0",
#   'The Return of the King '],
#  ['316',
#   'LEGOLAS',
#   'The horses are restless and the men are quiet.\xa0',
#   'The Return of the King '],
#  ['317',
#   'EOMER',
#   'They grow nervous in the shadow of the mountain.\xa0 \xa0',
#   'The Return of the King '],
#  ['318',
#   'GIMLI',
#   'That road there where does that lead?\xa0 \xa0',
#   'The Return of the King '],
#  ['319',
#   'LEGOLAS',
#   '\xa0It is the road to the Dimholt, the door under the mountain.\xa0 \xa0',
#   'The Return of the King '],
#  ['320', 'ORC', 'Catapults! , ha ha ha.    \xa0', 'The Return of the King '],
#  ['321',
#   'DENETHOR',
#   'My sons are spent! ,     My line has ended! \xa0',
#   'The Return of the King '],
#  ['322', 'PIPPIN', "He's alive! \xa0", 'The Return of the King '],
#  ['323',
#   'DENETHOR',
#   ' The     house of Stewards has failed. \xa0',
#   'The Return of the King '],
#  ['324',
#   'PIPPIN',
#   'He needs medicine my lord! \xa0',
#   'The Return of the King '],
#  ['325', 'DENETHOR', 'My line has ended! \xa0', 'The Return of the King '],
#  ['326', 'PIPPIN', 'My lord!\xa0', 'The Return of the King '],
#  ['327', 'DENETHOR', 'Rohan has deserted us! \xa0', 'The Return of the King '],
#  ['328',
#   'DENETHOR',
#   "Theoden's betrayed me! ABANDON YOUR POSTS! ,FLEE! FLEE FOR YOUR LIVES! ",
#   'The Return of the King '],
#  ['329',
#   'GANDALF',
#   'Prepare for battle. Hurry men! To the wall! Defend the wall! Over here!     Return to your posts.\xa0',
#   'The Return of the King '],
#  ['330',
#   'GANDALF',
#   'Send these foul beasts into the Abyss. \xa0',
#   'The Return of the King '],
#  ['331', 'GOTHMOG', 'Stay where you are! ', 'The Return of the King '],
#  ['332', 'SOLDIER', 'We need more rubble!\xa0', 'The Return of the King '],
#  ['333',
#   'EOMER',
#   'None who venture there ever return.\xa0 That mountain is evil.\xa0 \xa0',
#   'The Return of the King '],
#  ['334',
#   'GIMLI',
#   "Aragorn!\xa0 ,\xa0     Let's find some food.\xa0 \xa0",
#   'The Return of the King '],
#  ['335',
#   'EOWYN',
#   'There.\xa0 A true esquire of Rohan.\xa0 \xa0',
#   'The Return of the King '],
#  ['336',
#   'MERRY',
#   "I'm ready!\xa0 , Sorry.\xa0 It isn't all that dangerous.\xa0 It's not     even sharp.\xa0 \xa0",
#   'The Return of the King '],
#  ['337', 'EOWYN', 'To the smithy, go!\xa0 \xa0', 'The Return of the King '],
#  ['338',
#   'EOMER',
#   '     You should not encourage him.\xa0',
#   'The Return of the King '],
#  ['339',
#   'EOWYN',
#   'You should not doubt him.\xa0 \xa0',
#   'The Return of the King '],
#  ['340',
#   'EOMER',
#   'I do not doubt his heart, only the reach of his arm.\xa0    \xa0',
#   'The Return of the King '],
#  ['341',
#   'EOWYN',
#   'Why should Merry be left behind?\xa0 He has as much cause to go to war as     you.\xa0 Why can he not fight for those he loves?\xa0 \xa0',
#   'The Return of the King '],
#  ['342',
#   'EOMER',
#   'You know as little of war as that Hobbit.\xa0\xa0 When the fear takes him    , and the blood and the     screams and the horror of battle take hold.\xa0 Do you think he would stand and     fight?\xa0 He would flee.\xa0 And he would be right to do so.\xa0    ,\xa0 War is the     province of men Eowyn.\xa0 \xa0',
#   'The Return of the King '],
#  ['343',
#   'SOLDIER',
#   'Sir?\xa0 King Theoden awaits you my lord.\xa0 \xa0',
#   'The Return of the King '],
#  ['344', 'SOLDIER', 'Watch out! \xa0', 'The Return of the King '],
#  ['345',
#   'SOLDIER',
#   'Down to the lower levels quick! \xa0',
#   'The Return of the King '],
#  ['346', 'SOLDIER', 'Double up men! \xa0', 'The Return of the King '],
#  ['347',
#   'GANDALF',
#   'Hold them back, do not give in to fear. Stand to your posts. Fight! \xa0',
#   'The Return of the King '],
#  ['348',
#   'GANDALF',
#   'Not at the towers! Aim for the trolls, kill the trolls!\xa0',
#   'The Return of the King '],
#  ['349', 'GANDALF', 'Bring them down! \xa0', 'The Return of the King '],
#  ['350',
#   'GANDALF',
#   'Fight them back! ,Peregrin Took! Go back to the Citadel.\xa0',
#   'The Return of the King '],
#  ['351',
#   'PIPPIN',
#   'They called us out to fight. \xa0',
#   'The Return of the King '],
#  ['352',
#   'GANDALF',
#   'This is no place for a Hobbit! \xa0',
#   'The Return of the King '],
#  ['353',
#   'GANDALF',
#   'Guard of the Citadel indeed! , Now back up the hill     quickly. Quick! \xa0',
#   'The Return of the King '],
#  ['354',
#   'GOTHMOG',
#   'What are you doing you useless scum? \xa0',
#   'The Return of the King '],
#  ['355',
#   'ORC',
#   "The door wont give. It's too strong. \xa0",
#   'The Return of the King '],
#  ['356', 'THEODEN', 'I take my leave. \xa0', 'The Return of the King '],
#  ['357', 'ARAGORN', ' My lord Elrond\xa0', 'The Return of the King '],
#  ['358',
#   'ELROND',
#   "I come on behalf of one whom I love.\xa0 Arwen is dying.\xa0 She will not long     survive the evil that now spreads from Mordor.\xa0 The light of the evenstar is     failing.\xa0 As Sauron's power grows her strength wanes.\xa0 Arwen's life is now     tied to the fate of the Ring.\xa0 The Shadow is upon us Aragorn.\xa0 The end has     come.\xa0",
#   'The Return of the King '],
#  ['359',
#   'ARAGORN',
#   'It will not be our end, but his.\xa0 \xa0',
#   'The Return of the King '],
#  ['360',
#   'ELROND',
#   "\xa0 You ride to war     but not to victory.\xa0 Sauron's armies ride on Minas Tirith, this you know.\xa0     But in secret he sends another force, which will attack, from the river.    , A fleet of Corsair ships sails from the South.\xa0 They will be     in the city in two days.\xa0 You're outnumbered Aragorn.\xa0 You need more men.\xa0",
#   'The Return of the King '],
#  ['361', 'ARAGORN', 'There are none.\xa0', 'The Return of the King '],
#  ['362',
#   'ELROND',
#   '\xa0There are those that dwell in the mountain.\xa0 \xa0',
#   'The Return of the King '],
#  ['363',
#   'ARAGORN',
#   'Murderers, traitors. You would call upon them to fight?\xa0 They believe in     nothing.\xa0 They answer to no one\xa0',
#   'The Return of the King '],
#  ['364',
#   'ELROND',
#   "They will answer to the King of Gondor.\xa0 , And'ril, the Flame of the West, forged from the shards of     Narsil.\xa0 \xa0",
#   'The Return of the King '],
#  ['365',
#   'ARAGORN',
#   'Sauron will not have forgotten the sword of Elendil.\xa0 \xa0',
#   'The Return of the King '],
#  ['366',
#   'ARAGORN',
#   'The blade that was broken shall return to Minas Tirith.\xa0 \xa0',
#   'The Return of the King '],
#  ['367',
#   'ELROND',
#   "The man who can wield the power of this sword can summon to him an army     more deadly than any that walks this earth.\xa0 Put aside the Ranger.\xa0 Become     who you were born to be 'nen i-Estel Edain. \xa0",
#   'The Return of the King '],
#  ['368',
#   'ARAGORN',
#   "\xa0'-chebin Estel anim.\xa0 \xa0",
#   'The Return of the King '],
#  ['369',
#   'EOWYN',
#   'Why are you doing this?\xa0 The war lies to the East.\xa0 You cannot leave on     the eve of battle.\xa0 You cannot abandon the men.\xa0 \xa0',
#   'The Return of the King '],
#  ['370',
#   'PIPPIN',
#   'What were you thinking Peregrin Took?\xa0 What service can a Hobbit offer     such a great lord of men?\xa0\xa0 \xa0',
#   'The Return of the King '],
#  ['371',
#   'FARAMIR',
#   '\xa0,\xa0 It was     well done.\xa0 A generous deed should not be checked with cold counsel.\xa0    ,     You are to join the tower guard.\xa0',
#   'The Return of the King '],
#  ['372',
#   'PIPPIN',
#   "I didn't think they would find any livery that would\xa0 fit me. \xa0",
#   'The Return of the King '],
#  ['373',
#   'FARAMIR',
#   'It once belonged to a young boy of the city.\xa0 A very foolish one who     wasted many hours slaying dragons instead of attending his studies.\xa0 \xa0',
#   'The Return of the King '],
#  ['374', 'PIPPIN', 'This was yours?\xa0 \xa0', 'The Return of the King '],
#  ['375',
#   'FARAMIR',
#   'Yes, it was mine.\xa0 My father had it made for me.\xa0 \xa0',
#   'The Return of the King '],
#  ['376',
#   'GOTHMOG',
#   'Get back there and smash it down!\xa0',
#   'The Return of the King '],
#  ['377', 'ORC', 'But nothing can breach it! \xa0', 'The Return of the King '],
#  ['378',
#   'GOTHMOG',
#   "Grond will breach it! , Bring out the wolf's head.\xa0",
#   'The Return of the King '],
#  ['379',
#   'ORCS',
#   'Grond, Grond, Grond, Grond,     Grond!\xa0',
#   'The Return of the King '],
#  ['380',
#   'ORCS',
#   'Grond, Grond, Grond, Grond! \xa0',
#   'The Return of the King '],
#  ['381', 'ARAGORN', "Eowyn'\xa0", 'The Return of the King '],
#  ['382', 'EOWYN', 'We need you here.\xa0 \xa0', 'The Return of the King '],
#  ['383', 'ARAGORN', 'Why have you come?\xa0', 'The Return of the King '],
#  ['384', 'EOWYN', 'Do you not know?\xa0', 'The Return of the King '],
#  ['385',
#   'ARAGORN',
#   'It is but a shadow and a thought that you love.\xa0 I cannot give you what     you seek.\xa0\xa0',
#   'The Return of the King '],
#  ['386',
#   'ARAGORN',
#   '\xa0I have wished you joy since first I saw you. \xa0',
#   'The Return of the King '],
#  ['387',
#   'GIMLI',
#   " Just where do you     think you're off to?\xa0",
#   'The Return of the King '],
#  ['388',
#   'ARAGORN',
#   'Not this time.\xa0 This time you must stay Gimli.\xa0\xa0',
#   'The Return of the King '],
#  ['389', 'GIMLI', '\xa0Hmmmm\xa0', 'The Return of the King '],
#  ['390',
#   'LEGOLAS',
#   ' Have you learnt nothing of the stubbornness of     dwarves?\xa0 \xa0',
#   'The Return of the King '],
#  ['391',
#   'GIMLI',
#   "You might as well accept it.\xa0 We're going with you laddie.\xa0 Aragorn     smiles.\xa0",
#   'The Return of the King '],
#  ['392',
#   'SOLDIER',
#   "What's happening, where is he going?\xa0 I don't understand.\xa0 (, Lord Aragorn!\xa0 Why does     he leave on the eve of battle?\xa0 \xa0",
#   'The Return of the King '],
#  ['393',
#   'GAMLING',
#   'He leaves because there is no hope.\xa0',
#   'The Return of the King '],
#  ['394',
#   'THEODEN',
#   'He leaves because he must.\xa0 \xa0',
#   'The Return of the King '],
#  ['395',
#   'PIPPIN',
#   "Well, I'm taller than you were then.\xa0 Though, I'm not likely to grow     anymore, except sideways.\xa0 \xa0",
#   'The Return of the King '],
#  ['396',
#   'FARAMIR',
#   'It never fitted me either.\xa0 Boromir was always the soldier.\xa0    ,\xa0 They were so alike he and     my father.\xa0 Proud, stubborn even, but strong.\xa0 \xa0',
#   'The Return of the King '],
#  ['397',
#   'PIPPIN',
#   'I think you have strength of a different kind.\xa0 And one day your father     will see it.\xa0 \xa0',
#   'The Return of the King '],
#  ['398',
#   'PIPPIN',
#   "Here do I swear fealty and service to Gondor in peace or war, in living     or dying, from , ' from this hour henceforth     until my lord release me or death take me.\xa0",
#   'The Return of the King '],
#  ['399',
#   'DENETHOR',
#   'And I shall not forget it!\xa0,\xa0 nor fail to reward\xa0 that which is given.\xa0    ,\xa0     Fealty with love.\xa0 ,\xa0     Valour with honour.\xa0 Disloyalty with vengeance.\xa0     ,\xa0     I do not think we should so lightly abandon the outer defences.\xa0 Defences     that your brother long held intact.\xa0 \xa0',
#   'The Return of the King '],
#  ['400',
#   'FARAMIR',
#   'What would you have me do?\xa0',
#   'The Return of the King '],
#  ['401',
#   'DENETHOR',
# ...
#   'The Two Towers '],
#  ['849',
#   'THEODEN',
#   'We will cover the causeway and the gate from above. No army has ever     breached the Deeping Wall......or set foot inside the Hornburg!\xa0',
#   'The Two Towers '],
#  ['850',
#   'FARAMIR',
#   'It will grieve you then to     learn that he is dead.\xa0',
#   'The Two Towers '],
#  ['851', 'FRODO', 'Dead? How? When?\xa0', 'The Two Towers '],
#  ['852',
#   'FARAMIR',
#   "As one of his companions, I'd hoped you would tell me.\xa0",
#   'The Two Towers '],
#  ['853',
#   'FRODO',
#   'If something has happened to Boromir, we would have you tell us.\xa0',
#   'The Two Towers '],
#  ['854',
#   'FARAMIR',
#   'His horn washed up upon the riverbank, about six days past. It was     cloven in two. But more than this, I know it in my heart.    ,He was my brother.\xa0',
#   'The Two Towers '],
#  ['855',
#   'GIMLI',
#   'This is no rabble of mindless Orcs. These are Uruk-hai. Their armour is     thick and their shields broad.\xa0',
#   'The Two Towers '],
#  ['856',
#   'THEODEN',
#   'I have fought many wars, Master Dwarf. I know how to defend my own keep.\xa0',
#   'The Two Towers '],
#  ['857',
#   'THEODEN',
#   "They will break upon this fortress like water on rock.    ,Saruman's     hordes will pillage and burn.    We've seen it before. Crops can be resown......homes rebuilt. Within these     walls......we will outlast them.\xa0",
#   'The Two Towers '],
#  ['858',
#   'ARAGORN',
#   "They do not come to destroy Rohan's crops or villages. They come to     destroy its people......down to the last child.\xa0",
#   'The Two Towers '],
#  ['859',
#   'THEODEN',
#   'What would you have me do? Look at my men. Their courage hangs by a     thread. If this is to be our end, then I would have them make such an     end......as to be worthy of remembrance.\xa0',
#   'The Two Towers '],
#  ['860',
#   'ARAGORN',
#   'Send out riders, my lord. You must call for aid. \xa0',
#   'The Two Towers '],
#  ['861',
#   'THEODEN',
#   'And who will come? Elves? Dwarves? We are not so lucky in our friends as     you. The old alliances are dead.\xa0',
#   'The Two Towers '],
#  ['862', 'ARAGORN', 'Gondor will answer.\xa0', 'The Two Towers '],
#  ['863',
#   'THEODEN',
#   '(    Gondor?! Where was Gondor when the Westfold fell?! Where was Gondor when our     enemies closed in around us?! Where was Gon--? ,No, my Lord     Aragorn......we are alone. ,Get the women and children     into the caves.\xa0',
#   'The Two Towers '],
#  ['864',
#   'GAMLING',
#   'We need more time to lay provisions--\xa0',
#   'The Two Towers '],
#  ['865',
#   'ARWEN VOICEOVER',
#   'The light of the Evenstardoes not wax and wane.It is mine to give to whom I will.Like my heart.Go to sleep.\xa0',
#   'The Two Towers '],
#  ['866', 'ARAGORN ', 'I am asleep.,This is a dream.\xa0', 'The Two Towers '],
#  ['867', 'ARWEN', 'Then it is a good dream. ,Sleep. ', 'The Two Towers '],
#  ['868',
#   'ARAGORN',
#   "Minl' pendich nin i aur     hen telitha. ",
#   'The Two Towers '],
#  ['869',
#   'GOLLUM',
#   'We wants it.We needs it.Must have the precious.They stole it from us.Sneaky little Hobbitses.Wicked. Tricksy. False.\xa0',
#   'The Two Towers '],
#  ['870', 'SMEAGOL', 'No. Not master. \xa0', 'The Two Towers '],
#  ['871',
#   'GOLLUM',
#   'Yes, precious. False.They will cheat you, hurt you, lie! \xa0',
#   'The Two Towers '],
#  ['872', 'SMEAGOL', "Master's my friend.\xa0", 'The Two Towers '],
#  ['873',
#   'GOLLUM',
#   "You don't have any friends.Nobody likes you.\xa0",
#   'The Two Towers '],
#  ['874',
#   'SMEAGOL',
#   "Not listening. I'm not listening.\xa0",
#   'The Two Towers '],
#  ['875', 'GOLLUM', "You're a liar and a thief. \xa0", 'The Two Towers '],
#  ['876', 'SMEAGOL', 'No.\xa0', 'The Two Towers '],
#  ['877',
#   'THEODEN',
#   'There is no time. War is upon us. Secure the gate.\xa0',
#   'The Two Towers '],
#  ['878',
#   'TREEBEARD',
#   'We Ents have not troubled......about the wars of Men and     wizards......for a very long time. But now, something is about to     happen......that has not happened......for an age.,Entmoot.\xa0',
#   'The Two Towers '],
#  ['879', 'MERRY', "What's that?\xa0", 'The Two Towers '],
#  ['880', 'TREEBEARD', "'Tis a gathering.\xa0", 'The Two Towers '],
#  ['881', 'MERRY', 'A     gathering of what?\xa0', 'The Two Towers '],
#  ['882',
#   'TREEBEARD',
#   'Beech. Oak. Chestnut. Ash. Good. Good. Good. Many have come.,Now we must decide if the Ents......will     go to war.\xa0',
#   'The Two Towers '],
#  ['883',
#   'ARWEN',
#   "' i vethed... n' i onnad. Boe bedich go Frodo. Han b'd l'n. ",
#   'The Two Towers '],
#  ['884', 'ARAGORN', "Dolen i v'd o nin. ", 'The Two Towers '],
#  ['885',
#   'ARWEN',
#   "Si peliannen i v'd na dail l'n. Si boe '-dhannathach. ",
#   'The Two Towers '],
#  ['886', 'ARAGORN', 'Arwen....\xa0', 'The Two Towers '],
#  ['887',
#   'ARWEN',
#   "Ae '-esteliach nad...     estelio han. Estelio ammen. ",
#   'The Two Towers '],
#  ['888',
#   'EOWYN',
#   'Where is she?The woman who gave you that jewel.\xa0',
#   'The Two Towers '],
#  ['889',
#   'ELROND',
#   "Our time here is ending.Arwen's time is ending.Let her go.Let her take the ship into the west.Let her bear away her love for youto the Undying Lands.There it will be ever green.\xa0",
#   'The Two Towers '],
#  ['890', 'ARAGORN', 'But never more than memory.\xa0', 'The Two Towers '],
#  ['891',
#   'ELROND',
#   'I will not leave my daughter hereto die.\xa0',
#   'The Two Towers '],
#  ['892',
#   'ARAGORN',
#   'She stays because she still has hope.\xa0',
#   'The Two Towers '],
#  ['893',
#   'ELROND',
#   'She stays for you.She belongs with her people.\xa0',
#   'The Two Towers '],
#  ['894', 'ARWEN', 'Nach gwannatha sin? ', 'The Two Towers '],
#  ['895',
#   'ARWEN',
#   'Ma nathach hi gwannathach or minuial archened? \xa0',
#   'The Two Towers '],
#  ['896', 'GOLLUM', 'Murderer.\xa0', 'The Two Towers '],
#  ['897', 'SMEAGOL', 'Go away.\xa0', 'The Two Towers '],
#  ['898', 'GOLLUM', 'Go away? ', 'The Two Towers '],
#  ['899', 'SMEAGOL', 'I hate you.I hate you.\xa0', 'The Two Towers '],
#  ['900',
#   'GOLLUM',
#   'Where would you be without me?Gollum. Gollum.I saved us.It was me. We survived because of me.\xa0',
#   'The Two Towers '],
#  ['901', 'SMEAGOL', 'Not anymore.\xa0', 'The Two Towers '],
#  ['902', 'GOLLUM', 'What did you say?\xa0', 'The Two Towers '],
#  ['903',
#   'SMEAGOL',
#   "Master looks after us now.We don't need you.\xa0",
#   'The Two Towers '],
#  ['904', 'GOLLUM', 'What?\xa0', 'The Two Towers '],
#  ['905',
#   'SMEAGOL',
#   'Leave now......and never come back.\xa0',
#   'The Two Towers '],
#  ['906', 'GOLLUM', 'No.\xa0', 'The Two Towers '],
#  ['907', 'SMEAGOL', 'Leave now and never come back. \xa0', 'The Two Towers '],
#  ['908', 'SMEAGOL', 'Leave now and never come back!\xa0', 'The Two Towers '],
#  ['909',
#   'SARUMAN',
#   'Gandalf the White.Gandalf the Fool!Does he seek to humble mewith his newfound piety?\xa0',
#   'The Two Towers '],
#  ['910',
#   'GRIMA',
#   'There were threewho followed the wizard.An Elf, a Dwarf and a Man.\xa0',
#   'The Two Towers '],
#  ['911',
#   'SARUMAN',
#   'You stink of horse.The Man......was he from Gondor?\xa0',
#   'The Two Towers '],
#  ['912',
#   'GRIMA',
#   'No, from the North.One of the Dunedain RangersI thought he was.His cloth was poor.And yet he bore a strange ringTwo serpents with emerald eyes..\xa0One devouringthe other crowned with golden flowers.\xa0',
#   'The Two Towers '],
#  ['913',
#   'SARUMAN',
#   "The Ring of Barahir.So Gandalf Greyhamethinks he has found lsildur's heir.The lost king of Gondor.He is a fool.The line was broken years ago. ,It matters not.The world of Men shall fall.It will begin at Edoras.\xa0",
#   'The Two Towers '],
#  ['914',
#   'THEODEN',
#   'I am ready, Gamling.Bring my horse.\xa0',
#   'The Two Towers '],
#  ['915',
#   'THEODEN',
#   'This is not a defeat. We will return.,We will return.\xa0',
#   'The Two Towers '],
#  ['916', 'ARAGORN', "'-ethelithon. ", 'The Two Towers '],
#  ['917',
#   'ARWEN',
#   " Estelio guru l'n ne dagor.     Ethelithach. ",
#   'The Two Towers '],
#  ['918', 'ARAGORN', "'-bedin o gurth ne dagor. ", 'The Two Towers '],
#  ['919', 'ARWEN', ' O man pedich?    ', 'The Two Towers '],
#  ['920',
#   'ARAGORN',
#   "Edra le men, men na guil edwen. Haer o auth a n'r a naeth. ",
#   'The Two Towers '],
#  ['921', 'ARWEN', 'Why are you saying this?\xa0', 'The Two Towers '],
#  ['922',
#   'ARAGORN',
#   'I am mortal. You are Elf-kind.It was a dream, Arwen.Nothing more.\xa0',
#   'The Two Towers '],
#  ['923', 'ARWEN', "I don't believe you. \xa0", 'The Two Towers '],
#  ['924', 'ARAGORN', 'This belongs to you.\xa0', 'The Two Towers '],
#  ['925', 'ARWEN', 'It was a gift.Keep it.\xa0', 'The Two Towers '],
#  ['926', 'EOWYN', 'My lord?\xa0', 'The Two Towers '],
#  ['927',
#   'ARAGORN',
#   'She is sailing to the Undying Landswith all that is left of her kin.\xa0',
#   'The Two Towers '],
#  ['928', 'GAMLING', 'What is it? Hama?\xa0', 'The Two Towers '],
#  ['929', 'HAMA', "I'm not sure.\xa0", 'The Two Towers '],
#  ['930', 'GAMLING', 'Wargs!\xa0', 'The Two Towers '],
#  ['931', 'LEGOLAS', 'A scout!\xa0', 'The Two Towers '],
#  ['932',
#   'SMEAGOL',
#   'We told him to go away.And away he goes, precious. ,Gone! Gone! Gone!Smeagol is free!\xa0',
#   'The Two Towers '],
#  ['933',
#   'GOLLUM',
#   'Look.Look. See what Smeagol finds?\xa0',
#   'The Two Towers '],
#  ['934',
#   'GOLLUM',
#   'They are young.They are tender. They are nice.Yes, they are. Eat them. Eat them!    ',
#   'The Two Towers '],
#  ['935',
#   'SAM',
#   "You'll make him sick, you will......behaving like that.    ,There's only one way to eata brace of coneys.\xa0",
#   'The Two Towers '],
#  ['936',
#   'GOLLUM',
#   "What's it doing?Stupid, fat Hobbit.It ruins it.\xa0",
#   'The Two Towers '],
#  ['937',
#   'SAM',
#   "What's to ruin? There's hardly any meaton them. \xa0",
#   'The Two Towers '],
#  ['938', 'SAM', 'What we need is a few good taters.\xa0', 'The Two Towers '],
#  ['939',
#   'GOLLUM',
#   "What's taters, precious?What's taters? Eh?\xa0",
#   'The Two Towers '],
#  ['940', 'SAM', 'Po-ta-toes.\xa0', 'The Two Towers '],
#  ['941',
#   'SAM',
#   'Boil them, mash themstick them in a stew.Lovely, big, golden chipswith a nice piece of fried fish. \xa0',
#   'The Two Towers '],
#  ['942', 'SAM', "Even you couldn't say no to that. \xa0", 'The Two Towers '],
#  ['943',
#   'GOLLUM',
#   'Oh, yes, we could.Spoil a nice fish. ,Give it to us raw...    ,...and wriggling.You keep nasty chips.\xa0',
#   'The Two Towers '],
#  ['944', 'SAM', "You're hopeless.\xa0", 'The Two Towers '],
#  ['945', 'SAM', 'Mr. Frodo?\xa0', 'The Two Towers '],
#  ['946', 'SAM', 'Who are they?\xa0', 'The Two Towers '],
#  ['947',
#   'ARAGORN',
#   'You have some skill with a blade.\xa0',
#   'The Two Towers '],
#  ['948',
#   'EOWYN',
#   'Women of this country learned long ago:Those without swordscan still die upon them.I fear neither death nor pain.\xa0',
#   'The Two Towers '],
#  ['949', 'ARAGORN', 'What do you fear, my lady?\xa0', 'The Two Towers '],
#  ['950',
#   'EOWYN',
#   'A cage.To stay behind bars until useand old age accept them.And all chance of valor has gonebeyond recall or desire.\xa0',
#   'The Two Towers '],
#  ['951',
#   'ARAGORN',
#   "\xa0You're a daughter of kings......a shieldmaiden of Rohan.I do not think that would be your fate. \xa0",
#   'The Two Towers '],
#  ['952',
#   'GRIMA',
#   "Theoden will not stay at Edoras.It's vulnerable. He knows this.,He will expect an attack on the city.,They will flee to Helm's Deep......the great fortress of Rohan.,It is a dangerous road to takethrough the mountains.,They will be slow.,They will have women and childrenwith them. \xa0",
#   'The Two Towers '],
#  ['953', 'SARUMAN', 'Send out your Warg-riders.\xa0', 'The Two Towers '],
#  ['954',
#   'SAM',
#   "Hey, stinker, don't go gettingtoo far ahead.\xa0",
#   'The Two Towers '],
#  ['955', 'FRODO', 'Why do you do that?\xa0', 'The Two Towers '],
#  ['956', 'SAM', 'What?\xa0', 'The Two Towers '],
#  ['957',
#   'FRODO',
#   'Call him names.Run him down all the time.\xa0',
#   'The Two Towers '],
#  ['958',
#   'SAM',
#   "Because.Because that's what he is, Mr. Frodo.There's naught left in himbut lies and deceit.It's the Ring he wants.It's all he cares about.\xa0",
#   'The Two Towers '],
#  ['959',
#   'FRODO',
#   "You have no idea what it did to him......what it's still doing to him.,I want to help him, Sam.\xa0",
#   'The Two Towers '],
#  ['960', 'SAM', 'Why?\xa0', 'The Two Towers '],
#  ['961', 'THEODEN', 'What is it? What do you see?\xa0', 'The Two Towers '],
#  ['962', 'ARAGORN', "Warg! We're under attack!\xa0", 'The Two Towers '],
#  ['963', 'ARAGORN', 'Get them out of here!\xa0', 'The Two Towers '],
#  ['964',
#   'THEODEN',
#   'All riders to the head of the column.\xa0',
#   'The Two Towers '],
#  ['965',
#   'GIMLI',
#   "Come on. Get me up here. I'm a rider.Come on!\xa0",
#   'The Two Towers '],
#  ['966',
#   'THEODEN',
#   "You must lead the peopleto Helm's Deep, and make haste.\xa0",
#   'The Two Towers '],
#  ['967', 'EOWYN', 'I can fight.\xa0', 'The Two Towers '],
#  ['968', 'THEODEN', 'No!You must do this, for me.\xa0', 'The Two Towers '],
#  ['969', 'THEODEN', 'Follow me!\xa0', 'The Two Towers '],
#  ['970', 'GIMLI', 'Forward. I mean, charge forward.\xa0', 'The Two Towers '],
#  ['971', 'EOWYN', ' Make for the lower ground!\xa0', 'The Two Towers '],
#  ['972', 'GIMLI', " That's it! Go on!\xa0", 'The Two Towers '],
#  ['973', 'EOWYN', 'Stay together!\xa0', 'The Two Towers '],
#  ['974', 'GIMLI', 'Bring your pretty face to my axe.\xa0', 'The Two Towers '],
#  ['975',
#   'GOLLUM',
#   "Wicked Men.Servants of Sauron.They are called to Mordor.The Dark One is gathering all armiesto him.It won't be long now.He will soon be ready.\xa0",
#   'The Two Towers '],
#  ['976', 'SAM', 'Ready to do what? \xa0', 'The Two Towers '],
#  ['977',
#   'GOLLUM',
#   'To make his war.The last war that will coverall the world in Shadow.\xa0',
#   'The Two Towers '],
#  ['978',
#   'FRODO',
#   "We've got to get moving. Come on, Sam. \xa0",
#   'The Two Towers '],
#  ['979', 'SAM', "Mr. Frodo.Look.It's an oliphaunt. \xa0", 'The Two Towers '],
#  ['980', 'SAM', 'No one at home will believe this.\xa0', 'The Two Towers '],
#  ['981', 'FRODO', 'Smeagol?\xa0', 'The Two Towers '],
#  ['982',
#   'FRODO',
#   "We've lingered here too long.Come on, Sam.\xa0",
#   'The Two Towers '],
#  ['983', 'SAM', "Wait! We're innocent travelers!\xa0", 'The Two Towers '],
#  ['984',
#   'FARAMIR',
#   'There are no travelers in this land.Only servants of the Dark Tower.\xa0',
#   'The Two Towers '],
#  ['985',
#   'FRODO',
#   'We are bound to an errand of secrecy.Those that claim to oppose the enemywould do well not to hinder us.\xa0',
#   'The Two Towers '],
#  ['986',
#   'FARAMIR',
#   'The enemy? ,His sense of duty was no lessthan yours, I deem.,You wonder what his name is......where he came from.,And if he was really evil at heart.,What lies or threats led himon this long march from home.,If he would not rather have stayed there......in peace.,War will make corpses of us all.,Bind their hands.',
#   'The Two Towers '],
#  ['987',
#   'GIMLI',
#   "It's true, you don't seemany Dwarf women.And in fact, they are so alikein voice and appearance......that they're often mistakenfor Dwarf men.\xa0",
#   'The Two Towers '],
#  ['988',
#   'FRODO',
#   'Because I have to believehe can come back.\xa0',
#   'The Two Towers '],
#  ['989', 'SAM', "You can't save him, Mr. Frodo.\xa0", 'The Two Towers '],
#  ['990',
#   'FRODO',
#   "What do you know about it?Nothing! ,I'm sorry, Sam. I don't knowwhy I said that.\xa0",
#   'The Two Towers '],
#  ['991',
#   'SAM',
#   "I do. ,It's the Ring.You can't take your eyes off it.I've seen you.You're not eating. You barely sleep. ,It's taken hold of you, Mr. Frodo. You have to fight it.\xa0",
#   'The Two Towers '],
#  ['992',
#   'FRODO',
#   "I know what I have to do, Sam.The Ring was entrusted to me.It's my task.Mine! My own!\xa0",
#   'The Two Towers '],
#  ['993',
#   'SAM',
#   "Can't you hear yourself?Don't you know who you sound like? \xa0",
#   'The Two Towers '],
#  ['994',
#   'GIMLI',
#   'That one counts as mine! ,Stinking creature.\xa0',
#   'The Two Towers '],
#  ['995', 'LEGOLAS', 'Aragorn!\xa0', 'The Two Towers '],
#  ['996', 'GIMLI', 'Aragorn?\xa0', 'The Two Towers '],
#  ['997',
#   'GIMLI',
#   'Tell me what happenedand I will ease your passing.\xa0',
#   'The Two Towers '],
#  ['998',
#   'SHARKU',
#   "He's......dead.He took a little tumble off the cliff.\xa0",
#   'The Two Towers '],
#  ...]

# %% [markdown]
# What you see here is a __two dimensional list__, or in other words: A list that contains other lists!
#
# Now that you have the CSV file as a list of lists, you can access the value at a particular row and column with the expression `exampleData[row][col]`, where `row` is the index of one of the lists in exampleData, and `col` is the index of the item you want from that list.

# %%
# Get the second column element of the second row
exampleData[0][1]
# Out:
# 'char'

# %% [markdown]
# ### Reading Data from Reader Objects in a for Loop
# For large CSV files, you’ll want to use the Reader object in a for loop. This avoids loading the entire file into memory at once.

# %%
import csv
exampleFile = open('lotr_clean.csv')
exampleReader = csv.reader(exampleFile, delimiter=';')
for row in exampleReader:
    print('Row #' + str(exampleReader.line_num) + ' ' + str(row[2]))
    # What do we have to do to show just the dialogs?
# Out:
# Row #1 dialog
# Row #2 Oh Smeagol Ive got one! , Ive got a fish Smeagol, Smeagol!
# Row #3 Pull it in! Go on, go on, go on, pull it in!
# Row #4 Arrghh!
# Row #5 Deagol!
# Row #6 Deagol!
# Row #7 Deagol!
# Row #8 Give us that! Deagol my love
# Row #9 Why?
# Row #10 Because' , it's my birthday and I wants it.
# Row #11  My precious.
# Row #12 They cursed us
# Row #13 Murderer)
# Row #14 'Murderer' they called us. They cursed us and drove us away.
# Row #15 Gollum' Gollum' Gollum' , and we wept precious. We wept to be so alone.
# Row #16 and cool, so nice for feet' and we only wish to catch a fish    , so juicy sweet.
# Row #17 And we forgot the taste of bread, the sound of trees and the softness of     the wind. We even forgot our own name.
# Row #18     Gandalf?
# Row #19     Oooohhh!
# Row #20     Frodo!
# Row #21     Aaaahh!
# Row #22     Gimli!
# Row #23 My precious!
# Row #24 Wake up! , Wake up!     ,Wake up sleepies! We must go, yes, we must go at once.
# Row #25 Haven't you had any sleep Mr Frodo?
# Row #26 And I've gone and had too much. , It must be getting late.
# Row #27 No, it isn't. It isn't midday yet. , The days are growing darker.
# Row #28 Come on! Must go! No time!
# Row #29 Not before Mr Frodo's had something to eat.
# Row #30 No time to lose silly!
# Row #31 Here.
# Row #32 What about you?
# Row #33 Oh no, I'm not hungry, leastways not for lembas bread.
# Row #34 Sam!
# Row #35     Aragorn!
# Row #36     Now come the days of the King. May they be blessed.
# Row #37     This day does not belong to one man, but to all. Let us together rebuild     this world, that we may share in the days of peace.
# Row #38     Et E'rello Endorenna ut'lien. Sinome maruvan ar Hildinyar tenn' Ambar-metta!
# Row #39     Hannon le.
# Row #40     My friends, , you bow to     no-one.
# Row #41     ,And thus     it was a Fourth Age of Middle Earth began. And the Fellowship of the Ring,     though eternally bound by friendship and love was ended.            Thirteen months to the day since Gandalf sent us on our long journey we find     ourselves looking upon a familiar sight.
# Row #42     We were home.
# Row #43     Alright!
# Row #44     Hey watch the pumpkin.
# Row #45     Goodnight lads.
# Row #46 Oh alright, but we don't have that much left. We have to be careful or     we are going to run out. You go ahead and eat that Mr Frodo. I've rationed     it, there should be enough.
# Row #47 For what?
# Row #48 The journey home.
# Row #49 Come Hobbitses, very close now. Very close to Mordor. No safe places here. Hurry.
# Row #50 It's good. Definitely from the Shire. ,Longbottom leaf eh?
# Row #51 uhh huh , I feel like I'm back at the Green Dragon.
# Row #52 Mmmm , Green Dragon!
# Row #53 A mug of ale in my hand. Putting my feet up on a settle after a hard     day's work.
# Row #54 Only, , you've never done a hard day's work.
# Row #55 Ahaha!
# Row #56 Welcome, my lords to Isengard!
# Row #57 You young rascals. A merry hunt you've led us on and now we find you     feasting and ' and smoking!
# Row #58     Hmm?
# Row #59     How do you pick up the threads of an old life? How do you go on, when in     your heart you begin to understand there is no going back? There are some     things that time cannot mend. Some hurts that go too deep, that have taken     hold.
# Row #60     Mr Frodo? What is it?
# Row #61     It's been four years to the day since Weathertop Sam. It's never really     healed.
# Row #62     , There and Back Again, a Hobbits tale     by Bilbo Baggins and the Lord of the Rings by Frodo Baggins. You finished     it.
# Row #63     Not quite. There's room for a little more.
# Row #64     Bilbo once told me his part in this tale would end. That each of us must     come and go in the telling. Bilbo's story was now over. There would be no     more journeys for him. , save one.
# Row #65     Tell me again lad, where are we going?
# Row #66     To the harbour Bilbo. The elves have accorded you a special honour. A place     on the last ship to leave Middle Earth.
# Row #67     Frodo, any chance of seeing that old Ring of mine again? The one I gave you?
# Row #68  We are sitting on a field of     victory enjoying a few well earned comforts , The salted pork is particularly good.
# Row #69 Salted pork'
# Row #70 Hobbits!
# Row #71 We're under orders from Treebeard who's taken over management of Isengard.
# Row #72 Hoooom, young master Gandalf, I'm glad you've come. Wood and water,     stock and stone I can master, but there is a Wizard to manage here locked in     his tower
# Row #73  , Show yourself.
# Row #74 Be careful. Even in defeat, Saruman is dangerous.
# Row #75 Well then let's just have his head and be done with it.
# Row #76 No, we need him alive. We need him to talk.
# Row #77 You have fought many wars and slain many men Theoden King and made peace afterwards. Can we not take counsel together as we once did, my old friend?Can we not have peace you and I?
# Row #78 We shall have peace'. We shall have peace when you answer for the     burning of the Westfold and the children that lie dead there! We shall have peace when the lives of the soldiers whose bodies were hewn even as they lay dead against the gates of the Hornburg' are avenged! When you hang from a gibbet for the sport of your own crows' we shall have peace!
# Row #79 Gibbets and crows! Dotard! What do you want Gandalf Grahame? Let me guess' the key of Orthanc? Or perhaps the keys of Barad D'r itself? Along with the crowns of the seven Kings and the rods of the Five Wizards!
# Row #80 Your treachery has already cost many lives. Thousands more are now at     risk. But you could save them Saruman. You were deep in the enemy's counsel.
# Row #81     I'm sorry uncle. I'm afraid I lost it.
# Row #82     Oh, pity. (He sighs.) I would have like to have held it one last time.
# Row #83     Oh! Well here is a sight I have never seen before.
# Row #84     The power of the three rings is ended. The time has come for the dominion of     men.
# Row #85      I Aear c'n ven na mar.
# Row #86     I think I'm quite ready for another adventure.
# Row #87     Farewell my brave Hobbits. , My work is now finished.    ,Here at last, on the     shores of the sea, comes the end of our Fellowship. , I will not say do not weep for not all     tears are an evil. , It is time Frodo.
# Row #88     What does he mean?
# Row #89     We set out to save the Shire Sam and it has been saved, but not for me.
# Row #90     , You don't mean that. You can't     leave.
# Row #91     The last pages are for you Sam.
# Row #92 So you have come here for information. I have some for you.    ,Something festers in the heart of Middle Earth. Something that you have failed to see. But the great eye has seen it! Even now he presses his advantage. His attack will come soon.     ,     You are all going to die! But you know this don't you Gandalf? You cannot think that this Ranger will ever sit upon the throne of Gondor. This exile, crept from the shadows will never be crowned King. ,Gandalf does not hesitate to sacrifice those who are closest to him' those he professes to love! Tell me, what words of comfort did you give the Halfling before you sent him to his doom? The path that you have set him on can only lead to death.
# Row #93 I've heard enough! Shoot him! Stick an arrow in his gob!
# Row #94 No! Come down Saruman and your life will be spared!
# Row #95 Save your pity and your mercy. I have no use for it!
# Row #96 Saruman'.. your staff is broken!
# Row #97 Grima! You need not follow him! You were not always as you are now. You were once a man of Rohan. Come down.
# Row #98 A man of Rohan? What is the house of Rohan but a thatched barn where brigands drink in the reek and their brats roll on the floor with the dogs? The victory at Helms Deep does not belong to you Theoden Horse Master. You are a lesser son of greater sires!
# Row #99 Grima'. Come down! Be free of him!
# Row #100 Free? He will never be free!
# Row #101 No!
# Row #102     My dear Sam, you cannot always be torn in two. , You will     have to be one and whole for many years. You have so much to enjoy and to be     and to do. Your part in the story will go on.
# Row #103     Well, I'm back.
# Row #104      I didn't think it would end this way.
# Row #105   End?  No, the journey doesn't end here.  Death is just another path, one that we all must take.    ,  The grey rain curtain of this world rolls back and all turns to silvered glass.  And then you see it.
# Row #106   What?  Gandalf?  See what?
# Row #107   White shores and beyond,  a far green country under a swift sunrise.
# Row #108   Well, , that's not  so bad.
# Row #109   No.  No it isn't.
# Row #110   Rally to me!  To meeee!
# Row #111      Feast on his flesh.
# Row #112      I will kill you if you touch him.
# Row #113      The City has fallen silent.  There is no warmth left in the sun.
# Row #114   It grows so cold.
# Row #115   It's just the damp of the first spring rain.
# Row #116   I do not believe this darkness will endure.
# Row #117   Look!  The Orcs, they're moving off!
# Row #118 Get down cur!
# Row #119 Ah!
# Row #120 Saruman! You were deep in the enemy's counsel. Tell us what you know!
# Row #121 You withdraw your guard and I will tell you where your doom will be     decided. I will not be held prisoner here!
# Row #122 Send word to all our allies and to every corner of Middle Earth that     still stands free. The enemy moves against us. We need to know where he will     strike.
# Row #123 The filth of Saruman is washing away. Trees will come back to live here. ,Young trees. Wild trees.
# Row #124 Pippin!
# Row #125 Bless my bark!
# Row #126 Peregrin Took. I'll take that my lad! Quickly now!
# Row #127   Do not come between the Nazg'l and his prey.
# Row #128   Late as usual, pirate scum. ,  There's knifework here needs doing. Come on you sea rats, get off your ships.
# Row #129   There's plenty for the both of us, may be best Dwarf win!
# Row #130   You fool!  No man can kill me.  Die now!
# Row #131   I am no man!
# Row #132   You see Mr Frodo some luck at last!
# Row #133   Move it, you slugs!
# Row #134   Come on!  Faster!
# Row #135   Come along you scum! ,  I'll whip you down to the bone!  Come on!  What have I told you.    ,  Get up!    ,  Come on you slugs!  You two are going straight to the front line!  Move it, come on!  Fall in!  Move it! Move it! Move it!
# Row #136   To the gate you slugs, now move it! ,  Don't you know we're at war?
# Row #137   Company halt!  Inspection!
# Row #138   Sam!  Help me!
# Row #139   Mr Frodo!
# Row #140   Stand up Mr Frodo.  Stand up!
# Row #141   It's so heavy!
# Row #142   Oh no!  What do I do? ,  What do I do?
# Row #143  Hit me!  Hit me Sam!  Start fighting!
# Row #144   Get off of me! ,  Nobody pushes me you filthy maggot!    ,  Get off of me!
# Row #145       Retreat! The city is breached. Fall back to the second level. Get the     women and children out. Get them out. Retreat.
# Row #146     Come on, come on!
# Row #147     Move into the city. Kill all in your path.
# Row #148   Break it up!  Break it up!
# Row #149   Oy!  I'll have your guts if you don't shut this rabble down!
# Row #150      Go Sam.  Now!
# Row #151   Move along scum!
# Row #152   Get back in the line you maggots!  Get back in the line you slugs!
# Row #153   I can't!  I can't' I can't manage the Ring Sam.  It's' it's' such a weight to carry.  It's such a weight.
# Row #154     Take them down!
# Row #155     Fight! Fight to the last man. Fight for your lives.
# Row #156     Gandalf! ,     Gandalf! Denethor has lost his mind. He's burning Faramir alive!
# Row #157     Up! Quickly!
# Row #158     ,     Go back to the abyss! Fall into the nothingness that awaits you and your     master!
# Row #159     Do you not know death when you see it, old man? , This is my hour!
# Row #160      Gandalf!
# Row #161     AAAAhhh! ,
# Row #162     You have failed! The world of men will fall.
# Row #163     ,  We're going that way, straight as we can.  There's no point carrying anything we're not sure to need.
# Row #164   Mr Frodo, look. ,  There is light and beauty up there that no shadow can touch.
# Row #165   Take mine. ,  There's a few drops left.
# Row #166   There will be none left for the return journey.
# Row #167   I don't think there will be a return journey Mr Frodo.
# Row #168   Frodo, get down! ,  Hide!
# Row #169      Frodo!
# Row #170   Where are they?
# Row #171   Let the Lord of the Black Land come forth! ,  Let justice be done upon him!
# Row #172   My master Sauron the Great bids thee welcome.
# Row #173  Is there any in this rout with authority to treat with me?
# Row #174   We do not come to treat with Sauron, faithless and accursed.    Tell your master this.  The armies of Mordor must disband.  He is to depart these lands, never to return.
# Row #175     Courage Merry. Courage for our friends.
# Row #176     Form ranks you maggots. Form ranks. Pikes in front, archers behind.
# Row #177     Eomer, take your Eored down the left flank
# Row #178     Flank ready!
# Row #179     Gamling, follow the King's banner down the centre. Grimbold! Take your company right after you pass the wall. Forth and fear no darkness!     , Arise! Arise riders of Theoden. Spears shall be shaken, shields shall be splintered, a sword day, a red day ere the sun rises!!
# Row #180     Whatever happens, stay with me. I'll look after you.
# Row #181     Ride now, ride now! Ride! Ride for ruin and the world's ending! DEATH!
# Row #182     DEATH!
# Row #183     DEATH!
# Row #184     DEATH!
# Row #185     DEATH!
# Row #186     DEATH!
# Row #187   Aha!  Old Greybeard!  I have a token I was bidden to show thee.
# Row #188   Frodo!
# Row #189   Frodo!
# Row #190   Silence!
# Row #191   No!
# Row #192   Silence!
# Row #193   The Halfling was dear to thee I see.  Know that he suffered greatly at the hands of his host.  Who would've thought one so small could endure so much pain?  And he did Gandalf, he did.
# Row #194     You may go no further.
# Row #195 You will not enter Gondor
# Row #196 Who are you to deny us passage?
# Row #197 Legolas, fire a warning shot past the boson's ear.
# Row #198 Mind your aim.
# Row #199 Oh! , That's     it, right, we warned you! Prepare to be boarded!
# Row #200 Boarded, by you and whose army?
# Row #201     DEATH!
# Row #202     Forth Eorlingas!
# Row #203     FIRE!
# Row #204     DEEEEAAATH!
# Row #205     CHAAAAARGE!
# Row #206     Fire at will!
# Row #207     Set a fire in our flesh!
# Row #208     Stay this madness!
# Row #209     You may triumph in the field of battle for a day, but against the power that     has risen in the east, there is no victory!
# Row #210     NOOOOOO, you will not take my son from me!
# Row #211     NO! Aaahhh
# Row #212     Faramir!
# Row #213     Aaaaaahhhh!
# Row #214     So passes Denethor, son of Ecthelion.
# Row #215  And who is this?  Isildur's heir?  It takes more to make a King than a broken Elvish blade.
# Row #216   I guess that concludes negotiations.
# Row #217      I do not believe it.  I will not.
# Row #218 This army.
# Row #219 In there.
# Row #220  What is this place?
# Row #221 Master must go inside the tunnel.
# Row #222 Now that I'm here I don't think I want to.
# Row #223 It's the only way. Go in' or go back.
# Row #224 I can't go back.
# Row #225 What's that smell.
# Row #226 Orcses' filth. Orcses come in here sometimes.
# Row #227 Hurry! This way.
# Row #228 Smeagol?
# Row #229 Over here.
# Row #230 Ah aah! Its sticky, what is it?
# Row #231  You'll see. Oh yes, you     will see.
# Row #232   Drive them to the river. ,
# Row #233   Make safe the city.,
# Row #234   Re-form the line!  Re-form the line!,
# Row #235   Sound the charge.  Take them head-on. Chaaarge! ,
# Row #236   Cut him down! ,
# Row #237   Take the reins, pull him left. ,  LEFT! ,
# Row #238   Aim for the heads! ,
# Row #239   Bring it down! Bring it down!  Bring it down!,
# Row #240   Merry! ,
# Row #241 Smeagol? (shouts) SMEAGOL! SMEAGOL!
# Row #242 Sam.
# Row #243 Ow!
# Row #244 And you Frodo Baggins, I give you the light of E'rendil, our most beloved star. , May it be a light for you in dark places, when all other lights go out.
# Row #245 Aiya E'rendil Elenion Ancalim'
# Row #246 Naughty little fly. Why does he cry? ,Caught in a web. Soon     you'll be eaten.
# Row #247 Got away did it precious? Not this time. Not this time.
# Row #248 NO!
# Row #249 It wasn't us. It wasn't us. ,Smeagol wouldn't hurt master. We promised. You must believe us. It was the precious. The precious made us do it.
# Row #250 I have to destroy it Smeagol. , I have to destroy it for both our sakes.
# Row #251 NO! , Aaaaaaaaa.
# Row #252 I'm so sorry Sam.     I'm so sorry.
# Row #253 What kind of army would linger in such a place?
# Row #254 One that is cursed. Long ago the men of the mountains swore an oath to     the last King of Gondor , to come to his aid, to fight. But when     the time came, when Gondor's need was dire, they fled vanishing into the     darkness of the mountain. And so Isildur cursed them, never to rest until     they had fulfilled their pledge. Who shall call them from the grey twilight,     the forgotten people? The heir of him to whom the oath they swore. From the     North shall he come, need shall drive him. He shall pass the door to the     Paths of the Dead.
# Row #255 The very warmth of my blood seems stolen away.
# Row #256 The way is shut. It was made by those who are dead , and the dead keep it. The     way is shut.
# Row #257 Brego!
# Row #258 I do not fear death!
# Row #259 This task was appointed to you, Frodo of the Shire. If you do not find a     way, no one will.
# Row #260 The scouts report Minas Tirith is surrounded. The lower level's in flames. Everywhere, legions of the enemy advance.
# Row #261 Time is against us. Make ready!
# Row #262 Take heart Merry. , It will soon be over
# Row #263 My lady. You are fair and brave and have much to live for    , and many who love you. I     know it is too late to turn aside. I know there is not much point now in     hoping. If I were a knight of Rohan capable of great deeds'but I'm not. I'm a Hobbit. And I know I can't save Middle Earth. I just want to help my friends; Frodo, Sam, Pippin. More than anything I wish I could see them again.
# Row #264 Prepare to move out!
# Row #265 Make haste. We ride through the night.
# Row #266 To battle
# Row #267 To battle
# Row #268 Back to the gate! Hurry!
# Row #269 Well this is a thing unheard of. An elf will go underground, where a     dwarf dare not. Oh. Oh, I'd never hear the end of it.
# Row #270 We must ride light and swift. It is a long road ahead and man and beast     must reach the end with the strength to fight.
# Row #271 Little Hobbits do not belong in war Master Meriadoc.
# Row #272 All my friends have gone to battle. I would be ashamed to be left     behind.
# Row #273 It is a three-day gallop to Minas Tirith and none of my riders can bear     you as a burdon.
# Row #274  I want to fight!
# Row #275 I will say no more.
# Row #276 Ride with me!
# Row #277 My lady!
# Row #278 Form up, move out! Form up, move out!
# Row #279  Ride! Ride now to Gondor.
# Row #280 What is it? What do you see?
# Row #281 I see shapes of men and of horses.
# Row #282 Where?
# Row #283 Pale banners like shreds of cloud. , Spears rise     like winter thickets through a shroud of mist. The dead are following. They     have been summoned.
# Row #284  The dead?     Summoned? I knew that! Huh. Huh. , Very good. Very good. , Legolas!
# Row #285 Do not look down.
# Row #286 Who enters my domain?
# Row #287 One who will have your allegiance.
# Row #288 The dead do not suffer the living to pass.
# Row #289 You will suffer me!
# Row #290 The way is shut! It was made by those who are dead. And the dead keep     it. (The Ghostly army closes around them) The way is shut! Now you must die!
# Row #291  I summon you to     fulfil your oath!
# Row #292 None but the King of Gondor may command me!
# Row #293 Make way for the King!  Make way, the King is here
# Row #294 My lord!
# Row #295  Hail to you sire!
# Row #296  I bring 500 men from the Westfold my lord.
# Row #297 We have 300 more from Fenmarch, Theoden King.
# Row #298 That blade was broken!
# Row #299 It has been remade. ,     Fight for us and regain your honour. What say you? ,What say you?
# Row #300 Ach! You waste your time Aragorn. They had no honour in life and they     have none now in death.
# Row #301 I am Isildur's heir. Fight for me and I will hold your oaths fulfilled.    ,What say you?
# Row #302 You have my word! Fight and I will release you from this living death!    , What say you?
# Row #303 Stand you traitors!
# Row #304 Out!
# Row #305 Legolas! Run!
# Row #306 We fight!
# Row #307 Open the gate, quick!
# Row #308 Quick! Hurry!
# Row #309 Faramir! Say not that he has fallen.
# Row #310 They were outnumbered! None survived.
# Row #311 Fear. The city is rank with it! Ha ha ha ha. Let us ease their pain.     Release the prisoners!
# Row #312 Where are the riders from Snowbourn?
# Row #313 None have come my lord.
# Row #314 Six thousand spears, less than half of what I had hoped for.
# Row #315 Six thousand will not be enough to break the lines of Mordor.
# Row #316   More will come
# Row #317 Every hour lost hastens Gondor's defeat.  ,  We have until dawn then we must ride.
# Row #318 The horses are restless and the men are quiet.
# Row #319 They grow nervous in the shadow of the mountain.
# Row #320 That road there where does that lead?
# Row #321  It is the road to the Dimholt, the door under the mountain.
# Row #322 Catapults! , ha ha ha.
# Row #323 My sons are spent! ,     My line has ended!
# Row #324 He's alive!
# Row #325  The     house of Stewards has failed.
# Row #326 He needs medicine my lord!
# Row #327 My line has ended!
# Row #328 My lord!
# Row #329 Rohan has deserted us!
# Row #330 Theoden's betrayed me! ABANDON YOUR POSTS! ,FLEE! FLEE FOR YOUR LIVES!
# Row #331 Prepare for battle. Hurry men! To the wall! Defend the wall! Over here!     Return to your posts.
# Row #332 Send these foul beasts into the Abyss.
# Row #333 Stay where you are!
# Row #334 We need more rubble!
# Row #335 None who venture there ever return.  That mountain is evil.
# Row #336 Aragorn!  ,      Let's find some food.
# Row #337 There.  A true esquire of Rohan.
# Row #338 I'm ready!  , Sorry.  It isn't all that dangerous.  It's not     even sharp.
# Row #339 To the smithy, go!
# Row #340      You should not encourage him.
# Row #341 You should not doubt him.
# Row #342 I do not doubt his heart, only the reach of his arm.
# Row #343 Why should Merry be left behind?  He has as much cause to go to war as     you.  Why can he not fight for those he loves?
# Row #344 You know as little of war as that Hobbit.   When the fear takes him    , and the blood and the     screams and the horror of battle take hold.  Do you think he would stand and     fight?  He would flee.  And he would be right to do so.     ,  War is the     province of men Eowyn.
# Row #345 Sir?  King Theoden awaits you my lord.
# Row #346 Watch out!
# Row #347 Down to the lower levels quick!
# Row #348 Double up men!
# Row #349 Hold them back, do not give in to fear. Stand to your posts. Fight!
# Row #350 Not at the towers! Aim for the trolls, kill the trolls!
# Row #351 Bring them down!
# Row #352 Fight them back! ,Peregrin Took! Go back to the Citadel.
# Row #353 They called us out to fight.
# Row #354 This is no place for a Hobbit!
# Row #355 Guard of the Citadel indeed! , Now back up the hill     quickly. Quick!
# Row #356 What are you doing you useless scum?
# Row #357 The door wont give. It's too strong.
# Row #358 I take my leave.
# Row #359  My lord Elrond
# Row #360 I come on behalf of one whom I love.  Arwen is dying.  She will not long     survive the evil that now spreads from Mordor.  The light of the evenstar is     failing.  As Sauron's power grows her strength wanes.  Arwen's life is now     tied to the fate of the Ring.  The Shadow is upon us Aragorn.  The end has     come.
# Row #361 It will not be our end, but his.
# Row #362   You ride to war     but not to victory.  Sauron's armies ride on Minas Tirith, this you know.      But in secret he sends another force, which will attack, from the river.    , A fleet of Corsair ships sails from the South.  They will be     in the city in two days.  You're outnumbered Aragorn.  You need more men.
# Row #363 There are none.
# Row #364  There are those that dwell in the mountain.
# Row #365 Murderers, traitors. You would call upon them to fight?  They believe in     nothing.  They answer to no one
# Row #366 They will answer to the King of Gondor.  , And'ril, the Flame of the West, forged from the shards of     Narsil.
# Row #367 Sauron will not have forgotten the sword of Elendil.
# Row #368 The blade that was broken shall return to Minas Tirith.
# Row #369 The man who can wield the power of this sword can summon to him an army     more deadly than any that walks this earth.  Put aside the Ranger.  Become     who you were born to be 'nen i-Estel Edain.
# Row #370  '-chebin Estel anim.
# Row #371 Why are you doing this?  The war lies to the East.  You cannot leave on     the eve of battle.  You cannot abandon the men.
# Row #372 What were you thinking Peregrin Took?  What service can a Hobbit offer     such a great lord of men?
# Row #373  ,  It was     well done.  A generous deed should not be checked with cold counsel.     ,     You are to join the tower guard.
# Row #374 I didn't think they would find any livery that would  fit me.
# Row #375 It once belonged to a young boy of the city.  A very foolish one who     wasted many hours slaying dragons instead of attending his studies.
# Row #376 This was yours?
# Row #377 Yes, it was mine.  My father had it made for me.
# Row #378 Get back there and smash it down!
# Row #379 But nothing can breach it!
# Row #380 Grond will breach it! , Bring out the wolf's head.
# Row #381 Grond, Grond, Grond, Grond,     Grond!
# Row #382 Grond, Grond, Grond, Grond!
# Row #383 Eowyn'
# Row #384 We need you here.
# Row #385 Why have you come?
# Row #386 Do you not know?
# Row #387 It is but a shadow and a thought that you love.  I cannot give you what     you seek.
# Row #388  I have wished you joy since first I saw you.
# Row #389  Just where do you     think you're off to?
# Row #390 Not this time.  This time you must stay Gimli.
# Row #391  Hmmmm
# Row #392  Have you learnt nothing of the stubbornness of     dwarves?
# Row #393 You might as well accept it.  We're going with you laddie.  Aragorn     smiles.
# Row #394 What's happening, where is he going?  I don't understand.  (, Lord Aragorn!  Why does     he leave on the eve of battle?
# Row #395 He leaves because there is no hope.
# Row #396 He leaves because he must.
# Row #397 Well, I'm taller than you were then.  Though, I'm not likely to grow     anymore, except sideways.
# Row #398 It never fitted me either.  Boromir was always the soldier.     ,  They were so alike he and     my father.  Proud, stubborn even, but strong.
# Row #399 I think you have strength of a different kind.  And one day your father     will see it.
# Row #400 Here do I swear fealty and service to Gondor in peace or war, in living     or dying, from , ' from this hour henceforth     until my lord release me or death take me.
# Row #401 And I shall not forget it! ,  nor fail to reward  that which is given.     ,      Fealty with love.  ,      Valour with honour.  Disloyalty with vengeance.      ,      I do not think we should so lightly abandon the outer defences.  Defences     that your brother long held intact.
# Row #402 What would you have me do?
# Row #403 I will not yield the River and Pellenor unfought.  Osgiliath must be     retaken.
# Row #404 My lord Osgiliath is over run.
# Row #405 Much must be risked in war.    Is there a Captain here who still has the     courage to do his lord's will?
# Row #406 You wish now that our places had been exchanged.  That I had died and     Boromir had lived.
# Row #407 Yes, I wish that.
# Row #408 To few have come.  We cannot defeat the armies of Mordor.
# Row #409  No, we cannot.  But we will meet them in battle nonetheless.
# Row #410 I have left instruction. , The people are to follow your rule in     my stead.     Take up my seat in the Golden Hall. Long may you defend Edoras, if the     battle goes ill.
# Row #411 What other duty would you have me do my lord?
# Row #412 Duty? ,     no. , I     would have you smile again, not grieve for those whose time has come. You     shall live to see these days renewed , ' and no more despair
# Row #413 Since you are robbed of Boromir I will do what I can in his stead.     ,     If I should return, think better of me father.
# Row #414 That will depend on the manner of your return.
# Row #415  Ech!
# Row #416 What are you up to?  Sneaking off are we?
# Row #417 Sneaking?  Sneaking?  Fat Hobbit is always so polite.  Smeagol shows     them secret ways that nobody else could find and they say 'sneak!'  Sneak?      Very nice friend, oh yes my precious very nice , very nice!
# Row #418 Alright!  Alright!  You just startled me is all.  What were you doing?
# Row #419 Sneaking.
# Row #420 Fine, have it your own way.  ,  I'm sorry to wake you Mr Frodo but we have to be     moving on.
# Row #421 It's dark still.
# Row #422 It's always dark here.  ,  It's gone!     , The elven bread!
# Row #423 What?  That's all we have left!
# Row #424 We can't hold them.  The city is lost.
# Row #425  Tell the men to break cover.  We ride for Minas Tirith.
# Row #426 Nazg'l!
# Row #427  Take cover!  Nazgul!  Fall     back.  Fall back to Minas Tirith!
# Row #428 He took it.  He must have.
# Row #429 Smeagol?  No, no, not poor Smeagol.  Smeagol hates nasty elf bread.
# Row #430 You're a lying rat!  What did you do with it?
# Row #431   He doesn't     eat it. , He can't have taken     it.
# Row #432  Look, what's this?  ,  Crumbs on his jacketses.  He took it! ,He took it! ,  I've seen him, he's always stuffing his face when master's     not looking.
# Row #433 That's a filthy lie!  ,      You stinking, two faced sneak!
# Row #434 Sam!
# Row #435 Call me'
# Row #436 Stop it!
# Row #437  I'll kill him!
# Row #438  Sam, no!
# Row #439  Oh my!   I'm sorry.  I didn't mean it to go so far.  I was just     so, so angry!  Here just' let's just rest a bit.
# Row #440  I'm all right.
# Row #441 No.  No you're not all right, you're exhausted.  It's that Gollum.  It's     this place.  It's that thing around your neck.  , I could help a bit.  I could carry it for     a while ,,     carry it for a while ,      I could carry it' I could carry it' Share the load' share the load' share     the load
# Row #442 Get away!
# Row #443 Fall back!  ,  Retreat!  Retreat!  Run for your lives!
# Row #444 The age of men is over.  The time of the Orc has come.
# Row #445 Keep going.  It's the Nazgul.  Take cover my lord.     ,     It's coming.
# Row #446 Its Mithrandir!  The White Rider!
# Row #447  Pull!
# Row #448 Mithrandir!  ,     They broke through our defences.  They've taken the bridge and the West     bank.  Battalions of Orcs are crossing the river.
# Row #449 It is as the Lord Denethor predicted!  Long has he foreseen this doom!
# Row #450  Foreseen and done nothing!
# Row #451 Faramir?  This is not the first Halfling to have crossed your path.
# Row #452 No.
# Row #453 You've seen Frodo and Sam?
# Row #454 Where?  When?
# Row #455 I don't want to keep it.  , I just want to help.
# Row #456 See?  See?  He wants it for himself.
# Row #457 Shut up you!  ,  Go away!  Get     out of here!
# Row #458 No Sam!  It's you!  ,      I'm sorry Sam.
# Row #459   But he's a liar!  He's poisoned     you against me.
# Row #460 You can't help me any more.
# Row #461 You don't mean that.
# Row #462 Go home.
# Row #463   Faramir!  Faramir!     , Your     father's will has turned to madness.  Do not throw away your life so     rashly.
# Row #464 Where does my allegiance lie if not here?  This is the city of the men     of N'menor.  I will gladly give my life to defend her beauty, her memory,     her wisdom.
# Row #465 Your father loves you Faramir.  ,  He will remember it before the end.
# Row #466 Can you sing Master Hobbit?
# Row #467  well, yes.  At least well     enough for my own people.  But we have no songs for great halls and evil     times.
# Row #468 Sauron's wrath will be terrible, his retribution swift.
# Row #469 The battle for Helm's Deep is over. The battle for Middle-earth is about to begin.
# Row #470 (looking back out to Mordor) All our hopes now lie with two little Hobbits...
# Row #471 In Ithilien.  Not two days ago.  Gandalf, they're taking the road to the     Morgul vale.
# Row #472 And then the pass of Cirith Ungol.
# Row #473 What does that mean? What's wrong?  He looks at Gandalf.
# Row #474 Faramir tell me everything.  Tell me all you know.
# Row #475  This is how you would serve your city?  You would risk its utter     ruin?
# Row #476 I did what I judged to be right.
# Row #477 What you judged to be right!  You sent the Ring of power into Mordor in     the hands of a witless Halfling!  It should have been brought back to the     citadel to be kept safe. Hidden.  Dark and deep in the vaults' not to be     used.  ,      unless, at the uttermost end of need.
# Row #478 I would not use the Ring.  Not if Minas Tirith were falling in ruin and     I alone could save her.
# Row #479 Ever you desire to appear lordly and gracious as a King of old.       Boromir would have remembered his father's need.   He would have brought me     a kingly gift
# Row #480  Boromir would not have brought the Ring.   He would have stretched     out his hand to this thing and taking it he would have fallen.
# Row #481 And why should your songs be unfit for my halls?  Come, sing me a song.
# Row #482 Home is behind, The world ahead, ,  And     there are many paths to tread, Through shadow, to the edge of night    ,      Until the stars are all alight. ,  Mist and shadow     cloud and shade, All shall fade, All shall , 'fade.
# Row #483 March, march!   March, march march!
# Row #484 ...somewhere in the wilderness.
# Row #485 I wonder if we'll ever be put into songs or tales.
# Row #486 What?
# Row #487 I wonder if people will ever say,      "Let's hear about Frodo and the Ring."      And they'll say,      "Yes! That's one of my favourite stories."      "Frodo was really courageous, wasn't he, Dad? "      "Yes, my boy. ,The most famousest of Hobbits.      And that's saying a lot.",
# Row #488 Well, you've left out one of the chief characters:      "Samwise the Brave."      I want to hear more about Sam.
# Row #489 Frodo wouldn't have got far      without Sam.
# Row #490 Now, Mr. Frodo, you shouldn't make fun. I was being serious.
# Row #491 So was l. ,
# Row #492 "Samwise the Brave."
# Row #493 Smeagol?
# Row #494 We're not going to wait for you. Come on.,
# Row #495 Master. Master looks after us. ,Master wouldn't hurt us.
# Row #496 Master broke his promise.
# Row #497 Don't ask Smeagol. Poor, poor Smeagol.
# Row #498 Master betrayed us. Wicked. Tricksy. False. ,We ought to wring his filthy little neck.,Kill him! Kill him! Kill them both! ,And then we take the precious......and we be the master!
# Row #499 You know nothing of this matter!
# Row #500 He would have kept it for his own.  And when he returned you would not     have known your son.
# Row #501       Boromir was loyal to me!   Not some wizard's pupil.
# Row #502 Father?
# Row #503 My son!  ,  Leave me!
# Row #504 Careful master!  Careful.   Very far to fall.  Very dangerous are the     stairs.
# Row #505 Come master.
# Row #506 Come to Smeagol.
# Row #507 Mr Frodo!  , Get back     you!  Don't touch him.
# Row #508 Why does he hates poor Smeagol?  What has Smeagol ever done to him?      Master?  ,Master carries a heavy     burden Smeagol knows, heavy heavy burden.  Fat one cannot know.  ,  He wants it.  He needs     it.  Smeagol sees it in his eye.  , Very soon he will ask you for it.  You     will see.   The fat one will take it from you!
# Row #509 Send forth all legions.  Do not stop the attack until the city is     taken.
# Row #510 But the fat Hobbit, he knows.      Eyes always watching.
# Row #511       Then we stabs them out. Put out his eyeses and make him crawl.
# Row #512 Yes. Yes. Yes.
# Row #513 Kill them both.
# Row #514 Yes. , No! No! ,It's too risky. It's too risky.
# Row #515 Where is he? Where has he gone? Hey, Gollum! Where are you?
# Row #516 Smeagol?
# Row #517 We could let , do it.
# Row #518 Yes. She could do it.
# Row #519 Yes, precious, she could. And then we takes it once they're dead.
# Row #520 Once they're dead. ,Ssssssssssssssh!
# Row #521 Come on, Hobbits. Long ways to go yet. , Smeagol will show you the way.
# Row #522 Stay out of the forest! Keep away from the trees!
# Row #523 Final count.....42.
# Row #524 Forty-two? That's not bad for a pointy-eared Elvish princeling. I myself am sitting pretty on 43.,
# Row #525  Forty-three.
# Row #526 He was already dead.
# Row #527 Slay them all!
# Row #528 What of the wizard?
# Row #529  I will break him.
# Row #530 Where are Theoden's riders?
# Row #531 Will Rohan's army come?  Mithrandir?
# Row #532 Courage is the best defence that you have now.
# Row #533 Follow me.
# Row #534 He was twitching.
# Row #535 He was twitching......because he's got my axe ,embedded in his nervous system!
# Row #536 He doesn't look too happy, does he?
# Row #537 Not too happy at all, Merry.
# Row #538 Still, I suppose the view would be quite nice from up there.
# Row #539 Oh, yes. It's a quality establishment. I hear the staff are very good.
# Row #540 What are you doing?
# Row #541 Nothing. The world's back to normal, that's all.
# Row #542 No, it isn't. I'm starving.
# Row #543 Good luck trying to find something decent around here. ,Probably only dead rats and      mouldy bread.,
# Row #544 Saruman's storeroom!
# Row #545 I don't believe it.
# Row #546 It can't be.
# Row #547 lt is!
# Row #548 Longbottom Leaf. ,The finest pipe-weed in South Farthing.
# Row #549 It's perfect. One barrel each.,Wait.      Do you think we should share it with Treebeard?
# Row #550 Share it? ,No. No. ,Dead plant and all that. Don't think he'd understand. ,Could be a distant relative.
# Row #551 I get it. Don't be hasty.
# Row #552  Exactly.      , Bar-hrum.
# Row #553 This is the old sewer. Runs right under the river through to the edge of the city.      You'll find cover in the woods there.
# Row #554 Captain Faramir......you have shown your quality, sir.
# Row #555 The very highest.
# Row #556 The Shire must truly be a great realm      Master Gamgee......where gardeners are held in high honor.
# Row #557 What road will you take once you reach the woods?
# Row #558 Gollum says there's a path......near Minas Morgul that climbs up into the mountains.,
# Row #559 Cirith Ungol?,
# Row #560 ls that its name?
# Row #561 No. ,No! , Yes.
# Row #562 Frodo......they say a dark terror dwells in the passes above Minas      Morgul. You cannot go that way.
# Row #563 lt is the only way. Master says we must go to Mordor, so we must try.
# Row #564 I must.
# Row #565  Go, Frodo. Go with the goodwill of all Men.,
# Row #566 Thank you.
# Row #567 May death find you quickly if you bring them to harm.
# Row #568 Come on, keep up.
# Row #569 Mr. Frodo didn't mean for them Rangers to hurt you. You know that, don't you?      He was trying to save you, see?
# Row #570 Save me?
# Row #571 So there's no hard feelings. Forgive and forget.
# Row #572 No, no, no hard feelings. Gollum, Gollum. ,Yes, master. Nice Hobbits.
# Row #573 Very decent of you. Very decent, indeed      Gollum.
# Row #574 Faramir! Orcs have taken the eastern shore. Their numbers are too great.      By nightfall we will be overrun.
# Row #575 Mr. Frodo?
# Row #576 It's calling to him, Sam. His Eye is almost on me.
# Row #577 Hold on, Mr. Frodo. You'll be all right.
# Row #578 Take them to my father. ,Tell him Faramir sends a mighty gift.      ,A weapon that will change our fortunes      in this war. ,
# Row #579 Do you want to know      what happened to Boromir? ,You want to know why your brother died?  He tried to take the Ring from Frodo after swearing an oath to protect him! ,He tried to kill him! The Ring drove your brother mad!
# Row #580 Watch out!
# Row #581 Mr. Frodo?
# Row #582 They're here.
# Row #583 They've come.
# Row #584 Nazgul!
# Row #585 Stay here. Keep out of sight. ,Take cover!
# Row #586 The fortress is taken. It is over.,
# Row #587 You said this fortress would never fall while your men defend it.      They still defend it. They have died defending it.
# Row #588 They are breaking in!
# Row #589 They're past the door!
# Row #590 Is there no other way for the women      and children to get out of the caves?
# Row #591 Is there no other way?
# Row #592 There is one passage. It leads into the mountains. But they will not get far.      The Uruk-hai are too many.
# Row #593  Tell the women and children      to make for the mountain pass. And barricade the entrance!
# Row #594 Aragorn! Fall back to the Keep! Get your men out of there!,
# Row #595 Nan Barad! Nan Barad! , Haldir, nan Barad! (
# Row #596 What are you doing? What are you stopping for?
# Row #597 Nan Barad! (To the Keep!)
# Row #598 Haldir!
# Row #599 So much death. ,  What can Men do against such reckless hate?
# Row #600 Ride out with me. ,Ride out and meet them.,
# Row #601 For death and glory.
# Row #602 For Rohan. For your people.
# Row #603 The sun is rising.
# Row #604 Look to my coming at first light on the fifth day. At dawn......Iook to the east.
# Row #605 Yes.........Yes.........The horn of Helm Hammerhand......shall sound in the Deep......one last time.
# Row #606 Yes!,
# Row #607 Let this be the hour      when we draw swords together. ,
# Row #608 Fell deeds, awake. Now for wrath......now for ruin and a red dawn.,
# Row #609 Forth Eorlingas!,
# Row #610 Gandalf.
# Row #611  Theoden King stands alone.,
# Row #612 Brace the gate!
# Row #613 Hold them!
# Row #614 To the gate. Draw your swords!
# Row #615 Make way! ( ,We cannot hold much longer!
# Row #616 Hold them!
# Row #617 How long do you need?
# Row #618 As long as you can give me.
# Row #619 Gimli!
# Row #620 Timbers! Brace the gate!
# Row #621 Come on. We can take them.
# Row #622 It's a long way.
# Row #623 Toss me.
# Row #624 Not alone. , Rohirrim!
# Row #625 Eomer.,
# Row #626 To the king!
# Row #627 Yes!
# Row #628 A hit. A fine hit.
# Row #629 Break the dam!  Release the river!
# Row #630 Pippin! Hold on!
# Row #631 Hold on, little Hobbits.
# Row #632 What are you doing?
# Row #633 Where are you going?
# Row #634 It's me. It's your Sam. Don't you know your Sam?
# Row #635 What?
# Row #636 I cannot jump the distance! You'll have to toss me!
# Row #637  Don't tell the Elf.
# Row #638 Not a word.
# Row #639 Shore up the door!
# Row #640 Make way!
# Row #641 Follow me to the barricade.
# Row #642 Watch our backs!
# Row #643 Throw another one over here!
# Row #644 Higher!
# Row #645 Hold fast the gate!
# Row #646  Gimli! Aragorn! Get out of there!
# Row #647 Aragorn!
# Row #648 Pull everybody back. Pull them back.
# Row #649 Fall back! Fall back!
# Row #650 I can't do this, Sam.
# Row #651 I know. It's all wrong.      ,By rights, we shouldn't even be here.      But we are. It's like in the great stories, Mr. Frodo. The ones that really mattered.      ,Full of darkness and danger they were.      And sometimes you didn't want to know the end.....because how could the end be happy?       How could the world go back      to the way it was...... when so much bad had happened?
# Row #652 Victory! We have victory!
# Row #653 But in the end, it's only a passing thing...... this shadow. Even darkness must pass.      A new day will come. And when the sun shines, it will shine out the clearer.      Those were the stories      that stayed with you......that meant something. Even if you were too small      to understand why. But I think, Mr. Frodo, I do understand. I know now.
# Row #654 Folk in those stories......had lots of chances of turning back, only they didn't.      They kept going......because they were holding on to something.
# Row #655 What are we holding on to, Sam?
# Row #656 That there's some good in this world, Mr. Frodo. And it's worth fighting for.
# Row #657 I think at last we understand one another, Frodo Baggins. ,
# Row #658 You know the laws of our country, the laws of your father. If you let them go      your life will be forfeit.
# Row #659 Then it is forfeit. Release them.,
# Row #660 They have broken through! The castle is breached. Retreat!
# Row #661 Fall back!
# Row #662 Retreat!
# Row #663 Hurry! Inside. Get them inside!
# Row #664 Into the Keep!
# Row #665 I will leave you at the western borders of the forest. You can make your way north      to your homeland from there.
# Row #666 Wait! Stop! Stop! Turn around. Turn around. Take us south.
# Row #667 South? But that will lead you past lsengard.
# Row #668 Yes. Exactly.,If we go south, we can slip      past Saruman unnoticed. The closer we are to danger, the farther we are from harm.      It's the last thing he'll expect.
# Row #669 That doesn't make sense to me.      But then......you are very small. ,Perhaps you're right. South it is, then.      Hold on, little Shirelings. ,I always like going south. Somehow it feels like going downhill.,
# Row #670  Are you mad? We'll be caught.
# Row #671 No, we won't. Not this time.
# Row #672 Look! Osgiliath burns!
# Row #673 Mordor has come.
# Row #674 The Ring will not save Gondor.      , It has only the power to destroy.      Please......Iet me go.
# Row #675 Hurry.
# Row #676 Faramir! You must let me go!
# Row #677 And those little family of field mice......that climb up sometimes, and they tickle me awfully.
# Row #678 They're always trying to get somewhere where they....
# Row #679 Many of these trees were my friends. Creatures I had known from nut and acorn.
# Row #680 I'm sorry, Treebeard.
# Row #681 They had voices of their own.
# Row #682 Saruman. A wizard should know better!
# Row #683 There is no curse in Elvish......Entish or the tongues of Men......for this treachery.
# ...
# Row #2179 Mordor.
# Row #2180 Yes, there it lies. This city has dwelt ever in the sight of its shadow.
# Row #2181 A storm is coming.
# Row #2182 This is not the weather of the world. This is a device of Sauron's     making. A broil of fume he sends ahead of his host. The Orcs of Mordor have     no love of daylight, so he covers the face of the sun to ease their passage     along the road to war. When the shadow of Mordor reaches this city it will     begin.
# Row #2183 Well' Minas Tirith' very impressive. ,So where are off to next?
# Row #2184 Oh, it's too late for that Peregrin. There's no leaving this city.    ,     Help must come to us.
# Row #2185 But I know you have something to do with it.
# Row #2186 Good gracious me!
# Row #2187 Before you came along we Bagginses were very well     thought of.
# Row #2188 Indeed?
# Row #2189 We never had any adventures, or did anything     unexpected.
# Row #2190 If you're referring to the incident with the dragon, I     was barely involved. All I did was give your uncle a little nudge out of the     door.
# Row #2191 Whatever you did, you've been officially labelled as a     'disturber of the peace.'
# Row #2192 Oh really?
# Row #2193 Gandalf! Gandalf!
# Row #2194 Fireworks Gandalf! Gandalf! Fireworks Gandalf!
# Row #2195 Hooooraaaay!
# Row #2196 Gandalf, I'm glad you're back.
# Row #2197 You treacherous little toad!
# Row #2198 No, no! Master!
# Row #2199 No Sam! Leave him alone!
# Row #2200 I heard it from his own mouth. He means to murder us.
# Row #2201 Never! Smeagol wouldn't hurt a fly! ,     Aaaagh he is a horrid, fat Hobbit who hates Smeagol and who makes up nasty lies!
# Row #2202 You miserable little maggot! I'll stove your head in!
# Row #2203 Sam!
# Row #2204 Call me a liar? You're a liar!
# Row #2205 Waaaah!
# Row #2206 If you scare him off then we are lost!
# Row #2207 I don't care! I can't do it Mr Frodo! I won't wait around for him to     kill us!
# Row #2208 I'm not sending him away.
# Row #2209 You don't see it do you? He's a villain.
# Row #2210 We can't do this by ourselves Sam. Not without a guide. I need you on my     side.
# Row #2211 No
# Row #2212 I think we are
# Row #2213 Ssh! Gandalf's thinking
# Row #2214 Merry!
# Row #2215 What!
# Row #2216 I'm hungry
# Row #2217 There's something down there
# Row #2218 It's Gollum
# Row #2219 Gollum!
# Row #2220 He's been following us for three days
# Row #2221 He escaped the dungeons of Barad-D'r!
# Row #2222 Escaped ,     or was set loose and now the Ring has drawn him here ,      He won't ever be rid of his need for it.  He hates and loves the Ring,     as he hates and loves himself.  Smeagol's life is a sad story    ,  Yes    , he was once called, before the Ring     found him. Before it drove him mad
# Row #2223 It's a pity Bilbo didnt kill him when he had the chance
# Row #2224 Pity ?  It was pity that stayed Bilbo's hand.      Many that live deserve death and many that die, deserve life. Can you give     it to them Frodo ? Do not be too eager to deal out death and judgement Even     the very wise cannot see all ends.  My heart tells me that Gollum has     some part to play, yet for good or ill.... before this is over.     ,     The pity of Bilbo, may rule the fate of many
# Row #2225 I wish the Ring had never come to me.  I wish none of     this had happened.
# Row #2226 So do all who live to see such times, but that is not for     them to decide.  All we have to decide is what to do with the time that     is given to us.  There are other forces at work in this world, Frodo,     besides the will of evil.  Bilbo was meant to find the Ring, in which     case you also were meant to have it and that is an encouraging thought.        Oh! Its that way
# Row #2227 Good Evening little masters.  What can I do for you ?     If you're looking for accomodation, we've got some nice, cosy hobbit sized     rooms available.  Always proud to cater to the little folk, Mr err... ?
# Row #2228  Underhill, my name's     Underhill
# Row #2229 Underhill , yes..
# Row #2230 We're friends of Gandalf the Grey. Can you tell him we've     arrived?
# Row #2231 Gandalf ?  ,Gandalf ? Oh yes!  I remember!  Elderly chap! Big grey     beard, pointy hat.  , Not seen     him for six months.
# Row #2232 What do we do now ?
# Row #2233 Sam. He'll be here.  He'll come.
# Row #2234 What's that ?
# Row #2235 This my friend, is a pint!
# Row #2236 It comes in pints ?
# Row #2237 hmmmhmmm
# Row #2238 I'm getting one!
# Row #2239 You've had a whole half already!
# Row #2240 That fellow's done nothing but stare at you since we     arrived!
# Row #2241 So am I dear boy. , So am I.
# Row #2242  No thank     you! We don't want any more visitors, well wishers or distant relations!
# Row #2243 And what about very old friends?
# Row #2244 Gandalf?
# Row #2245 Bilbo Baggins.
# Row #2246 My dear Gandalf!
# Row #2247 It's good to see you. One hundred and eleven years old     who would believe it. ,     You haven't aged a day!
# Row #2248 Come on, come in! Welcome, welcome. Oh, here we are.
# Row #2249 Tea or maybe something a little stronger? I've got a     few bottles of the Old Winyard left, 1296, a very good year, almost as old     as I am.
# Row #2250 It was laid down by my father, what say we open one eh?
# Row #2251 Just tea, thank you.
# Row #2252 Owwwh!
# Row #2253 I was expecting you sometime last week. Not that it     matters; you come and go as you please. Always have done and always will.
# Row #2254 I'm on your side Mr Frodo
# Row #2255 I know Sam, I know. Trust me. Come Smeagol.
# Row #2256  What time is it?
# Row #2257 I dreamed I saw a great wave climbing over green lands and above the     hills. I stood upon the brink. It was utterly dark in the abyss before my     feet. A light shone behind me but I could not turn ,     I could only stand there, waiting.
# Row #2258 Night changes many thoughts. Sleep Eowyn. Sleep while you can.
# Row #2259 The stars are veiled. Something stirs in the East, a sleepless malice , The eye of the enemy     is moving.
# Row #2260 What are you doing?
# Row #2261 Pippin!
# Row #2262      Pippin!
# Row #2263 Pippin! Are you mad?
# Row #2264 I just want to look at it, just one more time.
# Row #2265 Put it back!
# Row #2266 Pippin!
# Row #2267 No!
# Row #2268 He's remembered
# Row #2269      No, but the air doesnt smell so foul down here.  If in doubt, Meriadoc,     always follow your nose.
# Row #2270 Let me risk a little more light , Behold the     great realm and dwarf city of Dwarrowdelf.
# Row #2271 There's an eye-opener and no mistake
# Row #2272 Oh!
# Row #2273 Gimli!
# Row #2274 No, no , no
# Row #2275 Here lies Balin, son of Fundin, Lord of Moria.    ,  He is dead then.    ,  Its as I feared.
# Row #2276  We must move on,     we cannot linger.
# Row #2277       They have taken the Bridge and the second hall.  We have barred the     gates, but cannot hold them for long.  The ground shakes.  Drums    ,     Drums in the deep. We cannot get out. , A shadow moves in the dark.    , We cannot get out. They are     coming.
# Row #2278  Fool of a     Took!  ,  Throw yourself in next time, and rid us of your     stupidity!
# Row #2279 Frodo!
# Row #2280 Orcs!
# Row #2281 Get back! and     stay close to Gandalf.
# Row #2282      Excuse me. That man in the corner.  Who is he ?
# Row #2283 He's one of them rangers. They're dangerous folk they are.      Wandering the wilds.  What his right name is, I've never heard, but     round here, he's known as Strider.
# Row #2284 Strider
# Row #2285 Baggins.... Baggins.... Baggins ....Baggins!  Baggins!
# Row #2286 Baggins ?  Sure I know a Baggins!  He's over     there.  Frodo Baggins! He's my second cousin once removed on his     mother's side , and my     third cousin twice removed on his father's side, if you follow me.
# Row #2287 Pippin!
# Row #2288 Steady on!
# Row #2289 Oh!
# Row #2290 You cannot hide!  , I see you!    ,There     is no life in the void , Only death!
# Row #2291 You draw far too much attention to yourself Mr Underhill!
# Row #2292 What do you want ?
# Row #2293 A little more caution from you!  That is no trinket     you carry!
# Row #2294 I carry nothing
# Row #2295 Indeed , I can avoid being seen if I wish.      But to disappear entirely     That is a rare gift!
# Row #2296 You've caught me a bit unprepared I'm afraid urm we've     only got cold chicken and a bit of pickle oh and there's some cheese here,     oh no that wont do! Urm we've got raspberry jam, an apple tart    ,     but we've not much for afters. Oh no we're all right, I've found some sponge     cake! , I can make     you some eggs if you ' oh'. Gandalf?
# Row #2297 Just tea, thank you.
# Row #2298 Oh right. ,     You don't mind if I do, do you?
# Row #2299 Oh not at all!
# Row #2300 Bilbo! Bilbo Baggins!
# Row #2301  I'm not at     home! , It's the Sackville-Bagginses.
# Row #2302 I know you're in there!
# Row #2303 They're after the house! , They've never forgiven me for living this     long. I've got to get away from these confounded relatives hanging on the     bell all day, never giving me a moment's peace. , I want to see     mountains again, mountains Gandalf. , And     then find somewhere quiet where I can finish my book. Oh, tea!
# Row #2304 So you mean to go through with your plan then?
# Row #2305 Yes, yes, it's all in hand. All the arrangements are     made. , Oh, thank you.
# Row #2306 Frodo suspects something.
# Row #2307 Of course he does, he's a Baggins, not some blockheaded     Bracegirdle from Hardbottle.
# Row #2308 You will tell him wont you?
# Row #2309  Pippin!
# Row #2310 He is here!
# Row #2311 I see you!
# Row #2312 Pippin!
# Row #2313 Help! Gandalf help!
# Row #2314 Help him!
# Row #2315  Pippin!
# Row #2316 Fool of a Took!
# Row #2317 No.
# Row #2318 Look at me.
# Row #2319 Gandalf, forgive me!
# Row #2320 Look at me! What did you see?
# Row #2321 A tree, there was a white tree in a courtyard of stone. It was dead.    ,The city was burning.
# Row #2322 Minas Tirith? Is that what you saw?
# Row #2323 They have a cave troll!
# Row #2324 Agh!  Let them come There's one dwarf yet in Moria who     still draws breath.
# Row #2325 Pull!
# Row #2326 Who are you ?
# Row #2327 Are you frightened?
# Row #2328  Yes
# Row #2329 Not nearly frightened enough. I know what hunts you.
# Row #2330 Let him     go!  Or I'll have you Longshanks!
# Row #2331  You have a     stout heart little hobbit! But that will not save you.  You can no     longer wait for the wizard Frodo. They're coming
# Row #2332 What are they ?
# Row #2333 They were once men. Great Kings of Men.  The Sauron     the Deciever  gave to them nine rings of power. Blinded by their greed     they took them without question. One by one falling into darkness    ,Now they are slaves to his will. They are     the Nazg'l. Ringwraiths.  Neither living nor dead. At all times they     feel the presence of the Ring , Drawn to the power of the One    , They     will never stop hunting you.
# Row #2334 Where are you taking us ?
# Row #2335 Into the wild
# Row #2336  How do we know this Strider is a friend of Gandalf ?
# Row #2337 I think a servant of the enemy would look fairer, but feel     fouler.
# Row #2338 He's foul enough
# Row #2339 We have no choice but to trust him
# Row #2340 Yes, yes.
# Row #2341 He's very fond of you.
# Row #2342 I know, he'd probably come with me if I asked him to. I     think in his heart Frodo's still in love with the Shire, the woods, the     fields and the little rivers. I am old Gandalf. I know I don't look it, but     I'm beginning to feel it in my heart. , I feel     thin, sort of stretched like butter scraped over too much bread. I need a     holiday, a very long holiday. And I don't expect that I shall return. In     fact, I mean not to.
# Row #2343 Old Toby, the finest weed in the Southfarthing.
# Row #2344 Gandalf my old friend, this will be a night to     remember.
# Row #2345 I saw' I saw him! , I     could hear his voice in my head.
# Row #2346 And what did you tell him? Speak!
# Row #2347 He asked me my name. I didn't answer. He hurt me!
# Row #2348 What did you tell him about Frodo and the Ring?
# Row #2349 There was no lie in Pippin's eyes. A fool but an honest fool he remains.
# Row #2350 He told Sauron nothing of Frodo and the Ring. ,We've been strangely fortunate. Pippin saw in the Palantir a glimpse     of the enemy's plan. Sauron moves to strike the city of Minas Tirith.
# Row #2351 His defeat at Helm's Deep showed our enemy one thing.    , He knows the Heir of     Elendil has come forth ,     Men are not as weak as he supposed. There is courage still. Strength enough,     perhaps, to challenge him. Sauron fears this. He will not risk the peoples     of Middle Earth uniting under one banner. , He will raze Minas Tirith to the ground    , before he     sees a King return to the throne of men. If the beacons of Gondor are lit     Rohan must be ready for war.
# Row #2352 Tell me! Why should we ride to the aid of those who did not come to     ours? What do we owe Gondor?
# Row #2353 I will go!
# Row #2354 No!
# Row #2355 They must be warned!
# Row #2356  But where     is he leading us ?
# Row #2357 To Rivendell Master Gamgee.  To the House of Elrond.
# Row #2358 D'you hear that!  Rivendell! We're going to see the     elves!
# Row #2359 Gentlemen! We do not stop 'til nightfall
# Row #2360 What about breakfast ?
# Row #2361  You've     already had it
# Row #2362 We've had one yes.  What about second breakfast ?
# Row #2363 Don't think he knows about second breakfast Pippin
# Row #2364 What about elvenses ? Luncheon, Afternoon Tea, Dinner ?     Supper!  He knows about them, doesnt he ?
# Row #2365 I wouldn't count on it
# Row #2366 Pippin!
# Row #2367 They will be. ,     You must come to Minas Tirith by another road. Follow the river. Look to the     black ships. ,     Understand this, things are now in motion that cannot be undone. I ride for     Minas Tirith , and I     wont be going alone.
# Row #2368 Of all the Hobbits, Peregrin Took, you are the worst! Hurry! Hurry!
# Row #2369 Where are we going?
# Row #2370 Why did you look? Why do you always have to look?
# Row #2371 I don't know, I can't help it.
# Row #2372 You never can!
# Row #2373 I'm sorry alright? I won't do it again.
# Row #2374 Don't you understand? The enemy thinks you have the ring! He is going to     be looking for you Pip. They have to get you out of here.
# Row #2375 And you? You're coming with me? ,     Merry?
# Row #2376 Come on!
# Row #2377 How far is Minas Tirith?
# Row #2378 Three days ride as the Nazg'l flies. And you'd better hope we don't have     one of those on our tail.
# Row #2379 Here, something for the road.
# Row #2380 The last of the Longbottom Leaf?
# Row #2381 I know you've run out. You smoke too much Pippin.
# Row #2382 But, we'll see each other soon?
# Row #2383 Wont we?
# Row #2384 I don't know! I don't know whats going to happen.
# Row #2385 Merry?
# Row #2386 Run, Shadowfax show us the meaning of haste.
# Row #2387 Merry!
# Row #2388 Merry!
# Row #2389 He's always followed me everywhere I went since before we were tweens. I     would get him into the worst sort of trouble but I was always there to get     him out. Now he's gone. , Just     like Frodo and Sam.
# Row #2390 One thing I've learnt about Hobbits: They are a most hardy folk.
# Row #2391 Foolhardy maybe. He's a Took!

# %% [markdown]
# After you import the `csv module and make a `Reader` object from the CSV file, you can loop through the rows in the Reader object. Each row is a list of values, with each value representing a cell.
#
# The `print()` function call prints the number of the current row and the contents of the row. To get the row number, use the Reader object’s `line_num` variable, which contains the number of the current line.
#
# The `Reader` object can be looped over only once. To reread the CSV file, you must call csv.reader to create a Reader object.

# %% [markdown]
# ### Writer Objects
#
# A `Writer` object lets you write data to a CSV file. To create a `Writer` object, you use the `csv.writer()` function.

# %%
import csv
# First, call open() and pass it 'w' to open a file in write mode
# The newline='' is to pass around a Windows bug... Just include it.
outputFile = open('output.csv', 'w', newline='')
# This will create the object you can then pass to csv.writer() to create a Writer object.
outputWriter = csv.writer(outputFile, delimiter=',')
# writerow takes a list as an argument
outputWriter.writerow(['spam', 'eggs', 'bacon', 'ham'])
outputWriter.writerow(['Hello, world!', 'eggs', 'bacon', 'ham'])
outputWriter.writerow([1, 2, 3.141592, 4])
# close the file at the end!
outputFile.close()

# %% [markdown]
# Notice how the `Writer` object automatically escapes the comma in the value `'Hello, world!'` with double quotes in the CSV file. __The csv module saves you from having to handle these special cases yourself__.
#
# Are you still awake? Quiz time!
#
# * How do you write CSV files that use semicolons instead of commas?
# * How do you write CSV files that use tabulator spaces instead of commas?

# %% [markdown]
# ## Project: Removing the Header from CSV Files
#
# Now we will finally start to use Python for something useful - we would like to remove the header from CSV files. Of course, for one single file, we don't need a Python progam to do this. But think of a folder full of hundreds of CSV files! For these repetitive task, Python is the perfect tool! Think again about the inital XKCD comic I showed you.
#
# ![XCDK - Is it worth the time?](https://imgs.xkcd.com/comics/is_it_worth_the_time.png "XCDK - Is it worth the time?")
#
# The program will need to open every file with the .csv extension in the current working directory, read in the contents of the CSV file, and rewrite the contents without the first row to a file of the same name. This will replace the old contents of the CSV file with the new, headless contents.
#
# ### Step 0: Make a plan!
#
# As always, whenever you write a program that modifies files, be sure to backup the files, first just in case your program does not work the way you expect it to. You don’t want to accidentally erase your original files.
#
# At a *high level*, the program must do the following:
#
# 1. Find all the CSV files in the current working directory.
# 2. Read in the full contents of each file.
# 3. Write out the contents, skipping the first line, to a new CSV file.
#
# At the *code level*, this means the program will need to do the following:
#
# 1. Loop over a list of files from `os.listdir()`, skipping the non-CSV files.
# 2. Create a CSV Reader object and read in the contents of the file, using the `line_num` attribute to figure out which line to skip.
# 3. Create a CSV Writer object and write out the read-in data to the new file.
#
# For this project, open a new file editor window and save it as `removeCsvHeader.py`.
#
# ![](https://i.imgur.com/C4M9azM.png)

# %% [markdown]
# ### Step 1: Loop Through Each CSV File
#
# The `os.makedirs()` call will create a `headerRemoved` folder where all the headless CSV files will be written. A `for` loop on `os.listdir('.')` gets you partway there, but it will loop over all files in the working directory, so you’ll need to add some code at the start of the loop that skips filenames that don’t end with `.csv`. The `continue` statement makes the for loop move on to the next filename when it comes across a non-CSV file.

# %%
#! python3
# removeCsvHeader.py - Removes the header from all CSV files in the current
# working directory.

import csv, os

os.makedirs('headerRemoved', exist_ok=True)

# Loop through every file in the current working directory.
for csvFilename in os.listdir('.'):
    if not csvFilename.endswith('.csv'):
        continue    # skip non-csv files

    print('Removing header from ' + csvFilename + '...')

    # TODO: Read the CSV file in (skipping first row).

    # TODO: Write out the CSV file.
# Out:
# Removing header from output.csv...
# Removing header from lotr_clean.csv...

# %% [markdown]
# ### Step 2: Read in the CSV File
#
# The program doesn’t remove the first line from the CSV file. Rather, it creates a new copy of the CSV file without the first line. Since the copy’s filename is the same as the original filename, the copy will overwrite the original.
#
# The program will need a way to track whether it is currently looping on the first row. Add the following to `removeCsvHeader.py`.

# %%
#! python3
# removeCsvHeader.py - Removes the header from all CSV files in the current
# working directory.

import csv, os

os.makedirs('headerRemoved', exist_ok=True)

# Loop through every file in the current working directory.
for csvFilename in os.listdir('.'):
    if not csvFilename.endswith('.csv'):
        continue    # skip non-csv files

    print('Removing header from ' + csvFilename + '...')

    # Read the CSV file in (skipping first row).
    csvRows = []
    csvFileObj = open(csvFilename)
    readerObj = csv.reader(csvFileObj, delimiter=';')
    for row in readerObj:
        if readerObj.line_num == 1:
            continue    # skip first row
        csvRows.append(row)
    csvFileObj.close()

    # TODO: Write out the CSV file.

# %% [markdown]
# The `Reader` object’s `line_num` attribute can be used to determine which line in the CSV file it is currently reading. Another for loop will loop over the rows returned from the CSV `Reader` object, and all rows but the first will be appended to `csvRows`.
#
# As the `for` loop iterates over each row, the code checks whether `readerObj.line_num` is set to `1`. If so, it executes a `continue` to move on to the next row without appending it to `csvRows`. For every row afterward, the condition will be always be `False`, and the row will be appended to `csvRows`.

# %% [markdown]
# ### Step 3: Write Out the CSV File Without the First Row
#
# Now that csvRows contains all rows but the first row, the list needs to be written out to a CSV file in the headerRemoved folder.

# %%
#! python3
# removeCsvHeader.py - Removes the header from all CSV files in the current
# working directory.

import csv, os

os.makedirs('headerRemoved', exist_ok=True)

# Loop through every file in the current working directory.
for csvFilename in os.listdir('.'):
    if not csvFilename.endswith('.csv'):
        continue    # skip non-csv files

    print('Removing header from ' + csvFilename + '...')

    # Read the CSV file in (skipping first row).
    csvRows = []
    csvFileObj = open(csvFilename)
    readerObj = csv.reader(csvFileObj, delimiter=';')
    for row in readerObj:
        if readerObj.line_num == 1:
            continue    # skip first row
        csvRows.append(row)
    csvFileObj.close()

    # Write out the CSV file.
    csvFileObj = open(os.path.join('headerRemoved', csvFilename), 'w', newline='')
    csvWriter = csv.writer(csvFileObj)
    for row in csvRows:
        csvWriter.writerow(row)
    csvFileObj.close()

# %% [markdown]
# The CSV `Writer` object will write the list to a CSV file in `headerRemoved` using `csvFilename` (which we also used in the CSV reader). This will overwrite the original file.
#
# Once we create the `Writer` object, we loop over the sublists stored in `csvRows` and write each sublist to the file.
#
# After the code is executed, the outer `for` loop will loop to the next filename from `os.listdir('.')`. When that loop is finished, the program will be complete.
