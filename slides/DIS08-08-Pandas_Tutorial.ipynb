# %%
import pandas as pd

# %% [markdown]
# ## Getting Started with Pandas – Load your Data

# %%
data = pd.read_csv("titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Extra: Combining Dataframes

# %%
mydataset = {
'cars': ["BMW", "Volvo", "Ford"],
'passings': [3, 7, 2]
}

mydataset2 = {
'cars': ["BMW", "VW", "Toyota"],
'owned': [0, 1, 0]
}

df = pd.DataFrame(mydataset)

df2  = pd.DataFrame(mydataset2)

# concatenate
df3 = pd.concat([df, df2])

# merge
df4 = pd.merge(df, df2)

# %%
df
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
df3 = pd.concat([df, df2])
df3
# Out:
#      cars  passings  owned
# 0     BMW       3.0    NaN
# 1   Volvo       7.0    NaN
# 2    Ford       2.0    NaN
# 0     BMW       NaN    0.0
# 1      VW       NaN    1.0
# 2  Toyota       NaN    0.0

# %%
df4
# Out:
#   cars  passings  owned
# 0  BMW         3      0

# %% [markdown]
# ### Save your Dataframes

# %%
# For saving DataFrames, use binary Pickles
data.to_pickle("data_output.pkl")

# And for reading the pickled file
data_read = pd.read_pickle("data_output.pkl")

# %%
data_read
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Examining your Data – Find the Tasty Parts
#
# Pandas’ core data structure: Series Objects
# - one-dimensional labeled array capable of holding any single data type (integers, strings, floating point numbers, Python objects, etc.)
# - Can be created f.e. from Dicts, Lists or Arrays
# - Can have indices (for example when created from dictionaries,
# - If none are passed, an index will be created having the values
# [0, ..., len(data) - 1]
#
# Combine Series Objects and you get DataFrames
# - 2-dimensional labeled data structure with columns of different
# types.
# - You can think of it like a spreadsheet or SQL table, or a dict of Series objects.
# - A DataFrame has columns and indices (row keys)

# %%
# Get indices or column names:
print("columns:\n",data.columns, "\n")
print("columns list:\n",list(data.columns), "\n")
print("columns list using Pandas fuction:\n",data.columns.to_list(), "\n")

print("are they the same?:",(list(data.columns) == data.columns.to_list()), "\n")


print(data.index, "\n")
print(type(data.index))
print(len(list(data.index)))
# Out:
# columns:
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# columns list:
#  ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# columns list using Pandas fuction:
#  ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']
#
# are they the same?: True
#
# RangeIndex(start=0, stop=891, step=1)
#
# <class 'pandas.core.indexes.range.RangeIndex'>
# 891

# %%
# Get columns of a DataFrame (as SeriesObject or list):
print(type(data.Name))
print(type(data.Name.to_list()))

len(data.Name.to_list())
# Out:
# <class 'pandas.core.series.Series'>
# <class 'list'>
# 891

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# also works for Series Objects
data.Age.describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data.mean()
# Out:
# <ipython-input-17-abc01cf6c622>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %% [markdown]
# ### Bonus: Export unique values of columns

# %%
print(data["Embarked"].unique())
print(data.Embarked.unique())
# Out:
# ['S' 'C' 'Q' nan]
# ['S' 'C' 'Q' nan]

# %% [markdown]
# ### Plot some!

# %%
data.Age.plot.hist()

# %% [markdown]
# ## Extra: Correlations

# %%
data.corr(method ='pearson')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
data.corr(method ='kendall')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.004090 -0.026824  0.027542 -0.048394  0.000798
# Survived       -0.004090  1.000000 -0.323533 -0.043385  0.085915  0.133933
# Pclass         -0.026824 -0.323533  1.000000 -0.286081 -0.039552 -0.021019
# Age             0.027542 -0.043385 -0.286081  1.000000 -0.142746 -0.200112
# SibSp          -0.048394  0.085915 -0.039552 -0.142746  1.000000  0.425241
# Parch           0.000798  0.133933 -0.021019 -0.200112  0.425241  1.000000
# Fare           -0.008921  0.266229 -0.573531  0.093249  0.358262  0.330360
#
#                  Fare
# PassengerId -0.008921
# Survived     0.266229
# Pclass      -0.573531
# Age          0.093249
# SibSp        0.358262
# Parch        0.330360
# Fare         1.000000

# %%
data.corr(method ='spearman')
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.034091  0.041010 -0.061161  0.001235
# Survived       -0.005007  1.000000 -0.339668 -0.052565  0.088879  0.138266
# Pclass         -0.034091 -0.339668  1.000000 -0.361666 -0.043019 -0.022801
# Age             0.041010 -0.052565 -0.361666  1.000000 -0.182061 -0.254212
# SibSp          -0.061161  0.088879 -0.043019 -0.182061  1.000000  0.450014
# Parch           0.001235  0.138266 -0.022801 -0.254212  0.450014  1.000000
# Fare           -0.013975  0.323736 -0.688032  0.135051  0.447113  0.410074
#
#                  Fare
# PassengerId -0.013975
# Survived     0.323736
# Pclass      -0.688032
# Age          0.135051
# SibSp        0.447113
# Parch        0.410074
# Fare         1.000000

# %%
# meistens nicht sehr nützlich
data.plot.hist()

# %% [markdown]
# ## Selecting Data
#
# ### Retrieva a line

# %%
data.loc[4]
# Out:
# PassengerId                           5
# Survived                              0
# Pclass                                3
# Name           Allen, Mr. William Henry
# Sex                                male
# Age                                35.0
# SibSp                                 0
# Parch                                 0
# Ticket                           373450
# Fare                               8.05
# Cabin                               NaN
# Embarked                              S
# Name: 4, dtype: object

# %% [markdown]
# ### Retrieve cell content

# %%
# retrive position x of Series Object
print(data.Name.loc[256])

# or by loc at DataFrame#
print(data.loc[3,"Name"])

# retrieve from Dataframe by two positional values
print(data.iloc[4,3])
# Out:
# Thorne, Mrs. Gertrude Maybelle
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Allen, Mr. William Henry

# %% [markdown]
# ## Filter DataFrame by criteria:

# %%
above_35 = data.loc[data["Age"] > 35]

# %%
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Multiple criteria in boolean statement:

# %%
data.loc[(data["Age"] > 35) & (data["Survived"] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 11            12         1       1
# 15            16         1       2
# 25            26         1       3
# 52            53         1       1
# ..           ...       ...     ...
# 857          858         1       1
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# the statement returns Series Object with True and False Boolean Values 
print((data["Age"] > 35) & (data["Survived"] == 1))
type((data["Age"] > 35) & (data["Survived"] == 1))
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool
# pandas.core.series.Series

# %%
### NLP Usecase: Match Text by Regular Expression:

# %%
# check if it is Text (String Object)
type(data.loc[1, "Name"])
# Out:
# str

# %%
data.loc[(data["Name"].str.contains(r"^J.*"))]
# Out:
#      PassengerId  Survived  Pclass  \
# 8              9         1       3
# 70            71         0       2
# 103          104         0       3
# 113          114         0       3
# 172          173         1       3
# 202          203         0       3
# 217          218         0       2
# 302          303         0       3
# 368          369         1       3
# 391          392         1       3
# 395          396         0       3
# 402          403         0       3
# 444          445         1       3
# 455          456         1       3
# 473          474         1       2
# 569          570         1       3
# 579          580         1       3
# 586          587         0       2
# 597          598         0       3
# 600          601         1       2
# 611          612         0       3
# 640          641         0       3
# 719          720         0       3
# 721          722         0       3
# 753          754         0       3
# ...

# %%
# Extra: How many Johns are 
len(data[data["Name"].str.contains("John")])
# Out:
# 52

# %% [markdown]
# ### Extra: Drop Rows with NA

# %%
data = data.dropna()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ## Adding Data to the Dataframe

# %%
data.loc["One"] = 1
# Out:
# /home/fabian/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
# One            1         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.loc["Survived2"] = data["Survived"]
# Out:
# /home/fabian/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
data
# Out:
#            PassengerId  Survived  Pclass  \
# 1                  2.0       1.0     1.0
# 3                  4.0       1.0     1.0
# 6                  7.0       0.0     1.0
# 10                11.0       1.0     3.0
# 11                12.0       1.0     1.0
# ...                ...       ...     ...
# 879              880.0       1.0     1.0
# 887              888.0       1.0     1.0
# 889              890.0       1.0     1.0
# One                1.0       1.0     1.0
# Survived2          NaN       NaN     NaN
#
#                                                         Name     Sex   Age  \
# 1          Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3               Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 6                                    McCarthy, Mr. Timothy J    male  54.0
# 10                           Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                                  Bonnell, Miss. Elizabeth  female  58.0
# ...

# %% [markdown]
# ## Adding Columns by applying fuctions

# %%
data.loc["Surname"]= data.apply(lambda row: row["Name"].split(",")[0], axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-2f5837f7c516> in <module>
# ----> 1 data.loc["Surname"]= data.apply(lambda row: row["Name"].split(",")[0], axis=1)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
# ...

# %%
data.index

# %%
def fare_class(value):
    if value < 7:
        return 1
    elif value < 20:
        return 2
    elif value < 50:
        return 3
    elif value < 100:
        return 4
    else:
        return 5

# %%
fare_class(56)

# %%
data.loc["Fare_Class"] = data.apply(lambda row: fare_class(row["Fare"]), axis=1)

# %%
data

# %%
# add Dict as new entry (ignore index because Dict) 
data = data.append({"Name":"Muller, Peter", "Sex":"male", "Ticket":"PL 5393", "Embarked":"S"}, ignore_index=True)

# %%
data
